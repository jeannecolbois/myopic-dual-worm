# %% [markdown]
# Last update 03.02.2020
#
# Author : Jeanne Colbois
#
# Please send any comments, questions or remarks to Jeanne Colbois: jeanne.colbois@epfl.ch.
# The author would appreciate to be cited in uses of this code, and would be very happy to hear about potential nice developments.

# %%
# %load_ext line_profiler

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
# Import modules
import numpy as np # maths

from time import time# timer for debug
    # gather results obtained from the runs  

import KagomeFunctions_OBC as kf # "library"< allowing to work on Kagome
import KagomeDrawing as kdraw # "library" allowing to plot Kagome
import KagomeFT as kft
import AnalysisFunctions_OBC as af # functions to make the analysis code cleaner
    #plots using matplotlib
import matplotlib
import matplotlib.pyplot as plt
import StartStates as strst
import KagomeFT as kft
#import matplotlib.image as mpimg
# %matplotlib inline
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams.update({'font.size': 14})

# %%
#secondfoldername = ['../Analysis_PSI/Kagome_54-1_Demag_all/',]*2
#secondfilename = ['54-1_Demag2_5-BR_spin_config.txt','54-1_Demag2_5-TL_spin_config.txt']

#secondfoldername = ['../Analysis_PSI/Kagome_54-1_Demag_all/']*3
#secondfilename = ['54-1_Demag3_5-BL_spin_config.txt',
#                  '54-1_Demag3_5-BR_spin_config.txt',
#                  '54-1_Demag3_5-TL_spin_config.txt']

#secondfoldername = ['../Analysis_PSI/Kagome_54-1_Demag_all/']*2
#secondfilename = ['54-1_Demag4_5-BL_spin_config.txt',
#                  '54-1_Demag4_5-TL_spin_config.txt']

#secondfoldername = ['../Analysis_PSI/Kagome_54-1_Demag_all/']*3
#secondfilename = ['54-1_Demag5_5-BL_spin_config.txt',
#                  '54-1_Demag5_5-BR_spin_config.txt',
#                  '54-1_Demag5_5-TL_spin_config.txt']
#
#secondfoldername = ['../Analysis_PSI/Kagome_54-1_Demag_all/']*3
#secondfilename = ['54-1_Demag6_5-BL_spin_config.txt',
#                  '54-1_Demag6_5-BR_spin_config.txt',
#                  '54-1_Demag6_5-TL_spin_config.txt']
#
secondfoldername = ['../Analysis_PSI/ExperimentalDataAndAnalysis/Inputs/']
secondfilename = ['54-1_Demag7_1-BL_spin_config.txt']
secondfilename = ['54-1_Demag7_1-BR_spin_config.txt']
secondfilename = ['54-1_Demag7_1-TL_spin_config.txt']
secondfilename = ['54-1_Demag7_1-TR_spin_config.txt']
##
secondfilename = ['54-1_Demag7_2-BL_spin_config.txt']
secondfilename = ['54-1_Demag7_2-BR_spin_config.txt']
secondfilename = ['54-1_Demag7_2-TL_spin_config.txt']
secondfilename = ['54-1_Demag7_2-TR_spin_config.txt']
##
secondfilename = ['54-1_Demag7_3-BL_spin_config.txt']
secondfilename = ['54-1_Demag7_3-BR_spin_config.txt']
secondfilename = ['54-1_Demag7_3-TL_spin_config.txt']
secondfilename = ['54-1_Demag7_3-TR_spin_config.txt']
##
secondfilename = ['54-1_Demag7_4-BL_spin_config.txt']
secondfilename = ['54-1_Demag7_4-BR_spin_config.txt']
secondfilename = ['54-1_Demag7_4-TL_spin_config.txt']
secondfilename = ['54-1_Demag7_4-TR_spin_config.txt']

secondfilename = ['54-1_Demag7_5-BL_spin_config.txt']
secondfilename = ['54-1_Demag7_5-BR_spin_config.txt']
secondfilename = ['54-1_Demag7_5-TL_spin_config.txt']
secondfilename = ['54-1_Demag7_5-TR_spin_config.txt']
#
secondfoldername = ['../../Analysis_PSI/ExperimentalDataAndAnalysis/Inputs/']*20
#secondfoldername = ['../Analysis_PSI/ExperimentalDataAndAnalysis/Inputs/']*20
secondfilename = ['54-1_Demag7_1-BL_spin_config.txt',
                  '54-1_Demag7_1-BR_spin_config.txt',
                  '54-1_Demag7_1-TL_spin_config.txt',
                  '54-1_Demag7_1-TR_spin_config.txt',
                  '54-1_Demag7_2-BL_spin_config.txt',
                  '54-1_Demag7_2-BR_spin_config.txt',
                  '54-1_Demag7_2-TL_spin_config.txt',
                  '54-1_Demag7_2-TR_spin_config.txt',
                  '54-1_Demag7_3-BL_spin_config.txt',
                  '54-1_Demag7_3-BR_spin_config.txt',
                  '54-1_Demag7_3-TL_spin_config.txt',
                  '54-1_Demag7_3-TR_spin_config.txt',
                  '54-1_Demag7_4-BL_spin_config.txt',
                  '54-1_Demag7_4-BR_spin_config.txt',
                  '54-1_Demag7_4-TL_spin_config.txt',
                  '54-1_Demag7_4-TR_spin_config.txt',
                  '54-1_Demag7_5-BL_spin_config.txt',
                  '54-1_Demag7_5-BR_spin_config.txt',
                  '54-1_Demag7_5-TL_spin_config.txt',
                  '54-1_Demag7_5-TR_spin_config.txt']

# %%
L = 12
domap = True
compute = True
subtractm = False
periodic = True
testsquare = False
centered = False
SF = False
LParam = (L-1, L-1, 0)
fixedscale = True

# %%
## ----------------- FILE BY FILE SF COMPUTATION ---------------##

# %%
n = len(secondfilename)

factors = [177.2,176.4,176.1,176.2,
           176.1, 176.2, 176.1, 176.2,
           176.1, 176.2, 176.1, 176.2,
           177, 176.9, 177, 176.9,
           177, 176.9, 177.5, 177.7]
factorths = [0.99]*20
refids = [[1210,1058,1055,1300],[1055,1057,1054,1145],
         [1054,1056,1053,1144],[1055,1057,1054,1145],
         [994,996,982,1084],[1054,1056,1053,1144],
         [983,985,982,1073],[1144,990,987,1234],
         [1022,1024,1021,1088],[1021,1023,1020,1081],
         [1050,1052,1049,1116],[1052,1054,1051,1118],
         [1078,1080,1077,1144],[1032,1034,1031,1098],
         [1020,1022,1019,1086],[1000,1002,999,1066],
         [1018,1020,1017,1084],[1079,1081,1078,1145],
         [1030,1032,1029,1096],[966,968,965,1032]
]

### 7 1 BL
#factors = [177.2]
###refid = [1210,1058,1055,2020]#(2*L-1, 0, 0)
#refid = [1210,1058,1055,1300]#(L-1, L-1, 0)
#factorths = [0.99]
#
##7 1 BR
#factors = [176.4]
##refid = [1055,1057,1054,2354]#(2*L-1, L-1, 0)
#refid = [1055,1057,1054,1145]#(L-1, L-1, 0)
#factorths = [0.99]
#
##7 1 TL
#factors = [176.1]
#factorths = [0.98]
#refid = [1054,1056,1053,1144]#(L-1, L-1, 0)
#
##7 1 TR
#factors = [176.2]
#refid = [1055,1057,1054,1145]#(L-1, L-1, 0)
#factorths = [0.99]
#
### 7 2 BL
#factors = [176.1]
#factorths = [0.99]
##refid = [1054,1056,1053,1144]#(L-1, L-1, 0) (v1)
#refid = [994,996,982,1084]#(L-1, L-1, 0) (v2)
#
##7 2 BR
#factors = [176.2]
#refid = [1054,1056,1053,1144]#(L-1, L-1, 0)
#factorths = [0.99]
#
##7 2 TL
#factors = [176.1]
#factorths = [0.99]
#refid = [983,985,982,1073]#(L-1, L-1, 0)
#
##7 2 TR
#factors = [176.2]
#refid = [1144,990,987,1234]#(L-1, L-1, 0)
#factorths = [0.99]
#
#refids = 
####7 3 BL
#factors = [176.1]
#factorths = [0.99]
#refid = [1022,1024,1021,1088]#(L-1, L-1, 0) (v2)

##7 3 BR
#factors = [176.2]
#refid = [1021,1023,1020,1081]#(L-1, L-1, 0)
#factorths = [0.99]
#
##7 3 TL
#factors = [176.1]
#factorths = [0.99]
#refid = [1050,1052,1049,1116]#(L-1, L-1, 0)
#
##7 3 TR
#factors = [176.2]
#refid = [1052,1054,1051,1118]#(L-1, L-1, 0)
#factorths = [0.99]

####7 4 BL
#factors = [177]
#factorths = [0.99]
#refid = [1078,1080,1077,1144]#(L-1, L-1, 0)
#
##7 4 BR
#factors = [176.9]
#refid = [1032,1034,1031,1098]#(L-1, L-1, 0)
#factorths = [0.99]
#
##7 4 TL
#factors = [177]
#factorths = [0.99]
#refid = [1020,1022,1019,1086]#(L-1, L-1, 0)
#
##7 4 TR
#factors = [176.9]
#refid = [1000,1002,999,1066]#(L-1, L-1, 0)
#factorths = [0.99]

#[1030,1032,1029,1096],[966,968,965,1032]
####7 5 BL
#factors = [177]
#factorths = [0.99]
#refid = [1018,1020,1017,1084]#(L-1, L-1, 0)
##
##7 5 BR
#factors = [176.9]
#refid = [1079,1081,1078,1145]#(L-1, L-1, 0)
#factorths = [0.99]
##
##7 5 TL
#factors = [177.5]
#factorths = [0.99]
#refid = [1030,1032,1029,1096]#(L-1, L-1, 0)
##
##7 5 TR
#factors = [177.7]
#refid = [966,968,965,1032]#(L-1, L-1, 0)
#factorths = [0.99]

#nnloclist = [(11,12), (11,12), (11,12), (11,12),
#             (11,12), (11,12), (41,42), (41,42),
#             (41,42), (41,42), (42,43), (42,43),
#             (42,43), (42,43), (41,42), (41,42),
#             (42,43), (41,42), (42,43), (42,43)]
#distconds = [(0.95, 1.05), (1.68, 1.78), (1.95, 2.05), (2.59, 2.69), (2.95, 3.05),
#             (3.41, 3.52), (3.54, 3.67), (3.95, 4.05)]
imgfile = ""

#covlist = []
#varcovlist = []
#dlist = []
#vardlist = []



for i in range(len(secondfilename)):
    print("------------------- File number ", i, " ----------------------")
    factor = factors[i]
    factorth = factorths[i]
    refid = refids[i]
    configlist, x, y, sconf= af.LoadSpinConfigsLarge(secondfoldername[i], secondfilename[i],
                                                     imgfile, alpha = 1, factor = factor)
    spos = np.column_stack((x,y)).T/factor
    spos = spos.T
    pos_id = {}
    for k in range(len(spos)):
        pos_id[tuple(np.around(spos[k],decimals=1))] = k

    print("--- Positions ---")
    print("Index ", refid[0], " : ", spos[refid[0]])
    print("Index ", refid[1], " : ", spos[refid[1]])
    print("Index ", refid[2], " : ", spos[refid[2]])
    print("Index ", refid[3], " : ", spos[refid[3]])
    print("Difference 3 0 : ", spos[refid[3]] - spos[refid[0]])
    difference = [spos[refid[l]] - spos[refid[0]] for l in range(4)]

    rot,tr,m1m2,ijl,ijl_sconfig = af.DrawClusterOnConfig(secondfoldername[i], L, refid ,spos, LParam = LParam,
                                             factor = factor, factorth = factorth, domap = domap, alpha = 0.5, color = "green")
    
    distances_s1s2 = af.KagomeLatticeHistogram(x,y, factor=factor)
    
    if compute:
        spos = np.column_stack((x,y)).T/factor
        spos = np.dot(rot, spos)
        spos[0,:] += tr[0]
        spos[1,:] += tr[1]
        spos = spos.T
        
        if testsquare:
            sconf = abs(sconf)
            secondfilename = ["test_square"]
        
        if SF:
            # %lprun -f af.StrctFact [StrctFact, m] = af.StrctFact(ijl, ijl_sconfig, m1m2, sconf, L, periodic = periodic, subtractm = subtractm, centered = centered)
            np.save(secondfoldername[i] + secondfilename[i][0:-4] + "_strctfact_subm={0}".format(subtractm) + "PBC={0}".format(periodic), StrctFact)
        else:
            [Correlations, m] =\
            af.SampleCorrelations(ijl, ijl_sconfig, sconf, L, subtractm = subtractm, centered = centered)
            np.save(secondfoldername[i] +
                    secondfilename[i][0:-4] +
                    "_correlations_subm={0}".format(subtractm) + "_Centered={0}".format(centered), Correlations)
            print("Correlations: ", Correlations)
            if centered:
                np.save(secondfoldername[i] +
                        secondfilename[i][0:-4] +
                        "_ReferenceConfiguration", m)
            else:
                np.save(secondfoldername[i] +
                        secondfilename[i][0:-4] +
                        "_AVGm_subcluster", m)
                
print("Done!")

# %%
if SF:
    size = (172/L)**2
    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
    kdraw.plot_function_reciprocal(np.real(StrctFact[:,0,0]), L, 2, s = size)
    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
    kdraw.plot_function_reciprocal(np.real(StrctFact[:,1,1]), L, 2, s = size)
    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
    kdraw.plot_function_reciprocal(np.real(StrctFact[:,2,2]), L, 2, s = size)
    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
    kdraw.plot_function_reciprocal(np.real(StrctFact[:,0,1]+StrctFact[:,1,0])/2, L, 2, s = size)
    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
    kdraw.plot_function_reciprocal(np.real(StrctFact[:,0,2]+StrctFact[:,2,0])/2, L, 2, s = size)
    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
    kdraw.plot_function_reciprocal(np.real(StrctFact[:,1,2]+StrctFact[:,2,1])/2, L, 2, s = size)
else:
    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
    kdraw.plot_function_kag(Correlations[0], L, 1.5, vmin = -1, vmax = 1)
    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
    kdraw.plot_function_kag(Correlations[1], L, 1.5, vmin = -1, vmax = 1)
    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
    kdraw.plot_function_kag(Correlations[2], L, 1.5, vmin = -1, vmax = 1)

# %%
## LOAD AND AVERAGE SFS ##

# %%
n = len(secondfilename)
mlist = [] 
SSList = []
for i in range(n):
    SSList.append(np.load(secondfoldername[i] + secondfilename[i][0:-4] + "_correlations_subm={0}".format(subtractm) +"_Centered=False.npy"))
    mlist.append(np.load(secondfoldername[i] + secondfilename[i][0:-4] + "_AVGm_subcluster.npy"))
AVGss = np.array(SSList)
AVGss = AVGss.sum(0)/n
AVGm = np.array(mlist).sum(0)/n
AVGCorrelations = AVGss - AVGm**2

if fixedscale:
    vmincorr = -1
    vmaxcorr = 1
else:
    vmincorr = None
    vmaxcorr = None


fig, ax = plt.subplots(figsize = (8,8),dpi=200)
kdraw.plot_function_kag(AVGCorrelations[0], L, 1.5, vmin = vmincorr, vmax = vmaxcorr)
fig, ax = plt.subplots(figsize = (8,8),dpi=200)
kdraw.plot_function_kag(AVGCorrelations[1], L, 1.5, vmin = vmincorr, vmax = vmaxcorr)
fig, ax = plt.subplots(figsize = (8,8),dpi=200)
kdraw.plot_function_kag(AVGCorrelations[2], L, 1.5, vmin = vmincorr, vmax = vmaxcorr)


np.save(secondfoldername[0] +
                "AVGCorrelations_subm={0}".format(subtractm) + "_Centered={0}".format(centered), AVGCorrelations)#

s_ijl, ijl_s =kf.createspinsitetable(L)
srefs = [ijl_s[(L-1,L-1,0)], ijl_s[(L-1,L-1,1)], ijl_s[(L-1,L-1,2)]]
AVGStrctFact = kft.StrctFact(L, AVGCorrelations, centered = True, srefs = srefs)

# %%
AVGCorrelations = np.load(secondfoldername[0] +
                "AVGCorrelations_subm={0}".format(subtractm) + "_Centered={0}".format(centered)+".npy")
s_ijl, ijl_s =kf.createspinsitetable(L)
srefs = [ijl_s[(L-1,L-1,0)], ijl_s[(L-1,L-1,1)], ijl_s[(L-1,L-1,2)]]

# %%
# Check first neighbours
NNcorr0 = (AVGCorrelations[0][ijl_s[(L-1,L-1,1)]]+
          AVGCorrelations[0][ijl_s[(L,L-1,2)]]+
          AVGCorrelations[0][ijl_s[(L,L-2,2)]]+
          AVGCorrelations[0][ijl_s[(L,L-2,1)]])/4
print(NNcorr0)
NNcorr1 = (AVGCorrelations[1][ijl_s[(L-1,L-1,0)]]+
          AVGCorrelations[1][ijl_s[(L-1,L-1,2)]]+
          AVGCorrelations[1][ijl_s[(L,L-1,2)]]+
          AVGCorrelations[1][ijl_s[(L-2,L,0)]])/4
print(NNcorr1)
NNcorr2 = (AVGCorrelations[2][ijl_s[(L-1,L-1,1)]]+
          AVGCorrelations[2][ijl_s[(L-2,L-1,0)]]+
          AVGCorrelations[2][ijl_s[(L-2,L-1,1)]]+
          AVGCorrelations[2][ijl_s[(L-2,L,0)]])/4
print(NNcorr2)
print("AVG",(NNcorr0+NNcorr1+NNcorr2)/3)

# %%
# check 2nd neighbours
N2corr0 = (AVGCorrelations[0][ijl_s[(L-1,L-1,2)]]+
          AVGCorrelations[0][ijl_s[(L,L-1,1)]]+
          AVGCorrelations[0][ijl_s[(L-1,L-2,1)]]+
          AVGCorrelations[0][ijl_s[(L+1,L-2,2)]])/4
print(N2corr0)
N2corr1 = (AVGCorrelations[1][ijl_s[(L-1,L-2,1)]]+
          AVGCorrelations[1][ijl_s[(L-2,L-1,0)]]+
          AVGCorrelations[1][ijl_s[(L-1,L,0)]]+
          AVGCorrelations[1][ijl_s[(L-1,L,2)]])/4
print(N2corr1)
N2corr2 = (AVGCorrelations[2][ijl_s[(L-1,L-1,0)]]+
          AVGCorrelations[2][ijl_s[(L-1,L-2,1)]]+
          AVGCorrelations[2][ijl_s[(L-2,L,1)]]+
          AVGCorrelations[2][ijl_s[(L-3,L,0)]])/4
print(N2corr2)
print("AVG",(N2corr0+N2corr1+N2corr2)/3)

# %%
# check 3rd neighbours //
N3corr0 = (AVGCorrelations[0][ijl_s[(L-1,L,0)]]+
          AVGCorrelations[0][ijl_s[(L-2,L,0)]]+
          AVGCorrelations[0][ijl_s[(L,L-2,0)]]+
          AVGCorrelations[0][ijl_s[(L-1,L-2,0)]])/4
print(N3corr0)
N3corr1 = (AVGCorrelations[1][ijl_s[(L-2,L,1)]]+
          AVGCorrelations[1][ijl_s[(L-2,L-1,1)]]+
          AVGCorrelations[1][ijl_s[(L,L-1,1)]]+
          AVGCorrelations[1][ijl_s[(L,L-1,1)]])/4
print(N3corr1)
N3corr2 = (AVGCorrelations[2][ijl_s[(L,L-1,2)]]+
          AVGCorrelations[2][ijl_s[(L-1,L,2)]]+
          AVGCorrelations[2][ijl_s[(L-1,L-2,2)]]+
          AVGCorrelations[2][ijl_s[(L-2,L-1,2)]])/4
print(N3corr2)
print("AVG",(N3corr0+N3corr1+N3corr2)/3)

# %%
np.save(secondfoldername[0] +
                    "AVGStrctFact_subm={0}".format(subtractm) + "_Centered={0}".format(centered), AVGStrctFact)

# %%
if fixedscale:
    vmindiag = 0.4
    vmaxdiag = 1.6
    vminoff = -0.6
    vmaxoff = 0.6
else:
    vmindiag = None
    vmaxdiag = None
    vminoff = None
    vmaxoff = None
size = (175/L)**2
fig, ax = plt.subplots(figsize = (8,8),dpi=200)
kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,0,0]), L, 2, s = size, vmin = vmindiag, vmax = vmaxdiag)
fig, ax = plt.subplots(figsize = (8,8),dpi=200)
kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,1,1]), L, 2, s = size, vmin = vmindiag, vmax = vmaxdiag)
fig, ax = plt.subplots(figsize = (8,8),dpi=200)
kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,2,2]), L, 2, s = size, vmin = vmindiag, vmax = vmaxdiag)
fig, ax = plt.subplots(figsize = (8,8),dpi=200)
kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,0,1]+AVGStrctFact[:,1,0])/2, L, 2, s = size, vmin = vminoff, vmax = vmaxoff)
fig, ax = plt.subplots(figsize = (8,8),dpi=200)
kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,0,2]+AVGStrctFact[:,2,0])/2, L, 2, s = size, vmin = vminoff, vmax = vmaxoff)
fig, ax = plt.subplots(figsize = (8,8),dpi=200)
kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,1,2]+AVGStrctFact[:,2,1])/2, L, 2, s = size, vmin = vminoff, vmax = vmaxoff)
fig, ax = plt.subplots(figsize = (8,8),dpi=200)
kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,0,0] +AVGStrctFact[:,1,1]+AVGStrctFact[:,2,2])/3, L, 2, s = size, vmin = vmindiag, vmax = vmaxdiag)

# %%
#n = len(secondfilename)
#
#if SF:
#    StrctFactList = []
#    for i in range(n):
#        StrctFactList.append(np.load(secondfoldername[i] + secondfilename[i][0:-4] + "_strctfact_subm={0}".format(subtractm) + "PBC={0}".format(periodic)+".npy"))
#    AVGStrctFact = np.array(StrctFactList)
#    AVGStrctFact = AVGStrctFact.sum(0)/20
#    vmin = -1
#    vmax = 1
#    size = (175/L)**2
#    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#    kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,0,0]), L, 2, s = size, vmin = vmin, vmax = vmax)
#    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#    kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,1,1]), L, 2, s = size, vmin = vmin, vmax = vmax)
#    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#    kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,2,2]), L, 2, s = size, vmin = vmin, vmax = vmax)
#    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#    kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,0,1]+AVGStrctFact[:,1,0])/2, L, 2, s = size, vmin = vmin, vmax = vmax)
#    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#    kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,0,2]+AVGStrctFact[:,2,0])/2, L, 2, s = size, vmin = vmin, vmax = vmax)
#    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#    kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,1,2]+AVGStrctFact[:,2,1])/2, L, 2, s = size, vmin = vmin, vmax = vmax)
#    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#    kdraw.plot_function_reciprocal(np.real(AVGStrctFact[:,0,0] +AVGStrctFact[:,1,1]+AVGStrctFact[:,2,2]), L, 2, s = size, vmin = vmin, vmax = vmax)
#else:
#    if subtractm:
#        CorrelationsList = []
#        for i in range(n):
#            CorrelationsList.append(np.load(secondfoldername[i] + secondfilename[i][0:-4] + "_correlations_subm={0}".format(subtractm) +".npy"))
#        AVGCorrelations = np.array(CorrelationsList)
#        AVGCorrelations = AVGCorrelations.sum(0)/20
#        
#        fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#        kdraw.plot_function_kag(AVGCorrelations[0], L, 1.5, vmin = -0.2, vmax = 0.2)
#        fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#        kdraw.plot_function_kag(AVGCorrelations[1], L, 1.5, vmin = -0.2, vmax = 0.2)
#        fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#        kdraw.plot_function_kag(AVGCorrelations[2], L, 1.5, vmin = -0.2, vmax = 0.2)
#    else:
#        mlist = [] # = average of the samples magnetisation
#        SSList = []
#        for i in range(n):
#            SSList.append(np.load(secondfoldername[i] + secondfilename[i][0:-4] + "_correlations_subm={0}".format(subtractm) +"_Centered=False.npy"))
#            mlist.append(np.load(secondfoldername[i] + secondfilename[i][0:-4] + "_AVGm_subcluster.npy"))
#        AVGss = np.array(SSList)
#        print(AVGss.shape)
#        print(AVGss[0,:,:])
#        AVGss = AVGss.sum(0)/n
#        print(AVGss)
#        AVGm = np.array(mlist).sum(0)/n
#        print(AVGm)
#        AVGCorrelations = AVGss - AVGm**2
#        
#        
#        
#        fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#        kdraw.plot_function_kag(AVGCorrelations[0], L, 1.5, vmin = -1, vmax = 1)
#        fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#        kdraw.plot_function_kag(AVGCorrelations[1], L, 1.5, vmin = -1, vmax = 1)
#        fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#        kdraw.plot_function_kag(AVGCorrelations[2], L, 1.5, vmin = -1, vmax = 1)
#        
#    
#    np.save(secondfoldername[0] +
#                    "AVGCorrelations_subm={0}".format(subtractm) + "_Centered={0}".format(centered), AVGCorrelations)#

# %%
#print([key for key in pos_id.keys() if key[0]> 24 and key[0] < 31 and key[1]>0 and key[1] <7])
#pos_id[(27.9,2.8)]

# %%
#print(difference)
#vec0 = spos[refid[0]]+np.array([6.95, 0.08])
#vec1 = vec0+difference[1]
#vec2 = vec0+difference[2]
#vec3 = vec0+difference[3]
#print(pos_id[tuple(np.around(vec0,decimals=1))])
#print(pos_id[tuple(np.around(vec1,decimals=1))])
#print(pos_id[tuple(np.around(vec2,decimals=1))])
#print(pos_id[tuple(np.around(vec3,decimals=1))])

# %%
## ----------------- FULL FIRST NEIGHBOUR CORRELS --------------##

# %%
#n = len(secondfilename)
#
#factors = [177, 178]
#nnloclist = [(11,12), (11,12)]
#
##factors = [178.34, 178.29, 178]
##nnloclist = [(11,12), (10,11), (11,12)]
#
##factors = [179, 179]
##nnloclist = [(10,11), (10,11)]
##
##factors = [179, 179, 180]
##nnloclist = [(10,11), (10,11), (11,12)]
##
#
##factors = [180, 177, 179]
##nnloclist = [(11,12), (11,12), (11,12)]
#
#factors = [178.27, 178, 177, 178,
#           177, 178, 178, 178,
#           178, 176.5, 178, 176.5,
#           179, 178.5, 178.5, 177,
#           177, 178, 178.5, 178.5]
#nnloclist = [(11,12), (11,12), (11,12), (11,12),
#             (11,12), (11,12), (41,42), (41,42),
#             (41,42), (41,42), (42,43), (42,43),
#             (42,43), (42,43), (41,42), (41,42),
#             (42,43), (41,42), (42,43), (42,43)]
##factors=[178, 176.5,
##           179, 178.5, 178.5, 177,
##           177, 178, 178.5, 178.5]
##nnloclist = [(42,43), (42,43),
##             (42,43), (42,43), (41,42), (41,42),
##             (42,43), (41,42), (42,43), (42,43)]
##
#distconds = [(0.95, 1.05), (1.68, 1.78), (1.95, 2.05), (2.59, 2.69), (2.95, 3.05), (3.41, 3.52), (3.54, 3.67), (3.95, 4.05)]
#imgfile = ""
#
#covlist = []
#varcovlist = []
#dlist = []
#vardlist = []
#
#
#for i in range(len(secondfilename)):
#    print("------------------- File number ", i, " ----------------------")
#    factor = factors[i]
#    configlist, x, y, sconf= af.LoadSpinConfigsLarge(secondfoldername[i], secondfilename[i], imgfile, alpha = 1, factor = factor)
#
#    plt.plot(x[nnloclist[i][0]]/factor, y[nnloclist[i][0]]/factor,'.', color = "red")
#    plt.plot(x[nnloclist[i][1]]/factor, y[nnloclist[i][1]]/factor,'.', color = "blue")
#    print(x[nnloclist[i][0]]," ", y[nnloclist[i][0]], " ", x[nnloclist[i][1]], " ", y[nnloclist[i][1]])
#    print(np.sqrt((x[nnloclist[i][0]]-x[nnloclist[i][1]])**2 + (y[nnloclist[i][0]]-y[nnloclist[i][1]])**2))
#    m = sum(sconf)/len(sconf)
#    print("magnetisation: ", m)
#    
#    distances_s1s2 = af.KagomeLatticeHistogram(x,y, factor=factor)
#    plt.savefig(secondfoldername[i] + 'Histogram' + secondfilename[i]+'.png')
#    plt.show()
#    NNList = af.KagomeLatticeNeighboursLists(distances_s1s2, distconds)
#    cconf, xc,yc, tlist = af.KagomeLatticeCharges(NNList,sconf,x,y)
#    charges = [np.count_nonzero(cconf == 3), np.count_nonzero(cconf == 1),
#           np.count_nonzero(cconf == -1), np.count_nonzero(cconf == -3)]
#    print(charges)
#    np.savetxt(secondfoldername[i] + 'charges' + secondfilename[i],
#           np.array(charges), newline=",")
#    
#    fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#    af.plotSpinSites(secondfoldername, imgfile, x, y, 
#                 [i for i in range(len(x)) if sconf[i] == 1],
#                 putimage = False, color = 'blue', alpha = 1,
#                 linestyle = 'none')
#    af.plotSpinSites(secondfoldername, imgfile, x, y, 
#                     [i for i in range(len(x)) if sconf[i] == -1],
#                     putimage = False, color = 'red', alpha = 1,
#                     linestyle = 'none')
#    af.plotSpinSites(secondfoldername, imgfile, xc, yc, 
#                     [i for i in range(len(xc)) if abs(cconf[i]) == 3], 
#                     putimage = False, color = 'yellow', alpha = 1,
#                     linestyle = 'none')
#    af.plotSpinSites(secondfoldername, imgfile, xc, yc, 
#                     [i for i in range(len(xc)) if abs(cconf[i]) == 1], 
#                     putimage = False, color = 'green', alpha = 1,
#                     linestyle = 'none')
#    plt.savefig(secondfoldername[i] + 'State_' + secondfilename[i]+'.png')
#    plt.show()
#
#    cov = []
#    varcov = []
#    d = []
#    vard = []
#
#    for j in range(9):
#        print(j)
#        cov0, varcov0, d0, vard0= af.ComputeNthCorrList(NNList[j], sconf, x, y, factor)
#        cov.append(cov0)
#        varcov.append(varcov0)
#        d.append(d0)
#        vard.append(vard0)
#      
#    covlist.append(cov)
#    varcovlist.append(varcov)
#    dlist.append(d)
#    vardlist.append(vard)
#    
#    
#        
#    del configlist
#    del x
#    del y
#    del sconf
#    del distances_s1s2
#    del NNList
#    del cconf
#    del xc
#    del yc
#    del charges
#    del cov
#    del varcov
#    del d
#    del vard
#

# %%
#d = np.array(dlist).sum(0)/n
#vard = np.array(vardlist).sum(0)/n
#
#cov = np.array(covlist).sum(0)/n
#varcov = np.array([(covlist[i] - cov)**2 for i in range(n)]).sum(0)/n
#
#varcov2 = np.array(varcovlist).sum(0)/n

# %%
#fig, ax = plt.subplots(dpi=200)
#plt.errorbar(d, np.array(cov),xerr = np.sqrt(np.array(vard)),yerr=np.sqrt(np.array(varcov)),  fmt= '.')
#plt.xlabel('Distance')
#plt.ylabel('Accumulated correlations')
#plt.ylim(-0.27,0.12)
#plt.savefig(secondfoldername[i] + 'FirstResult_' + secondfilename[i]+'.png')
#plt.show()

# %%
#ListNei = ['1', '2', '3par', '3star', '4', '5', '6', '6bis', '7', '8', '8bis','9']
#for i in range(n):
#    fig, ax = plt.subplots(figsize = (8,8), dpi=200)
#
#    for index, covi in enumerate(covlist[i][0:8]):
#        #print(index)
#        plt.errorbar(1, covi,yerr=np.sqrt(np.array(varcovlist[i])[index]), label='Neighbour {0}'.format(ListNei[index]),  fmt= 'x', )
#
#    plt.xlabel('')
#    plt.ylabel('Accumulated correlations')
#    plt.ylim(-0.27, 0.12)
#    plt.legend(loc='best')
#    plt.savefig(secondfoldername[i]+'FirstFewCorrelations'+secondfilename[i]+'.png')
#
#fig, ax = plt.subplots(figsize = (8,8),dpi=200)
#x = [1 for y in cov];
#
#for index, covi in enumerate(cov[0:8]):
#    print(index)
#    plt.errorbar(1, covi,yerr=np.sqrt(np.array(varcov2)[index]), label='Neighbour {0}'.format(ListNei[index]),  fmt= 'x', )
#plt.xlabel('')
#plt.ylabel('Accumulated correlations (20 samples average)')
#plt.ylim(-0.27, 0.12)
#plt.legend()
#plt.savefig(secondfoldername[0]+'AvgFirstFewCorrelations'+secondfilename[0]+'.png')

# %%
#for i in range(len(secondfilename)):
#    print("------------------- File number ", i, " ----------------------")
#    factor = factors[i]
#    configlist, x, y, sconf= af.LoadSpinConfigsLarge(secondfoldername[i], secondfilename[i], imgfile, alpha = 1, factor = factor)
#
#    print(len(x))
#        
#    del configlist
#    del x
#    del y
#    del sconf
#
