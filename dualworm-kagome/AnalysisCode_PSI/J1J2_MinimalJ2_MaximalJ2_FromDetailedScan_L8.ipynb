# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import csv

# %%
### FULL PICTURE ###

# %%
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# '/home/jeanne/miniconda3/envs/minimal/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'

# %% [markdown]
# ## The data given here is obtained from the RoleOfJ2 notebook with the L = 8 Scan

# %%
J2_lowT_c2c3par =  [0.0001, 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01]
lowT_c2c3par =  [0.01, 0.101, 0.207, 0.304, 0.395, 0.508, 0.616, 0.725, 0.905, 0.995, 1.245]
J2_lowT_c2c3parMin = [0.0001, 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01]
lowT_c2c3parMin = [0.01, 0.102, 0.214, 0.31, 0.419, 0.528, 0.627, 0.741, 0.94, 1.09, 1.305]
J2_lowT_c2c3parMax = [0.0001, 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.011]
lowT_c2c3parMax =  [0.01, 0.099, 0.2, 0.296, 0.388, 0.499, 0.603, 0.704, 0.876, 0.95, 1.178, 1.597]

J2_highT_c2c3par =  [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01]
highT_c2c3par =  [7.23, 7.762, 4.332, 4.365, 7.68, 3.649, 3.052, 2.523, 2.271, 2.215]
J2_highT_c2c3parMin =  [0.0001, 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01]
highT_c2c3parMin =  [6.07, 5.177, 6.06, 3.94, 4.229, 3.401, 2.919, 2.993, 2.452, 2.203, 1.805]
J2_highT_c2c3parMax =  [0.001, 0.004, 0.009, 0.01, 0.011]
highT_c2c3parMax =  [7.54, 6.155, 2.731, 2.308, 1.85]


J2_lowT_c2c3star =  [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017, 0.018, 0.019, 0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.05, 0.055, 0.06, 0.065, 0.07, 0.075, 0.08, 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.1, 0.1025, 0.105, 0.1075]
lowT_c2c3star =  [0.013, 0.026, 0.04, 0.052, 0.066, 0.079, 0.091, 0.105, 0.118, 0.13, 0.144, 0.158, 0.17, 0.183, 0.196, 0.209, 0.224, 0.237, 0.248, 0.262, 0.327, 0.392, 0.46, 0.528, 0.59, 0.658, 0.729, 0.797, 0.881, 0.967, 1.033, 1.148, 1.239, 1.292, 1.378, 1.423, 1.491, 1.582, 1.721, 1.787, 2.073, 2.061]
J2_lowT_c2c3starMin =  [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017, 0.018, 0.019, 0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.05, 0.055, 0.06, 0.065, 0.07, 0.075, 0.08, 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.1, 0.1025, 0.105, 0.1075]
lowT_c2c3starMin =  [0.013, 0.026, 0.04, 0.052, 0.066, 0.079, 0.092, 0.105, 0.119, 0.131, 0.145, 0.158, 0.17, 0.184, 0.197, 0.21, 0.225, 0.238, 0.249, 0.263, 0.328, 0.393, 0.461, 0.53, 0.591, 0.66, 0.732, 0.801, 0.885, 0.971, 1.039, 1.154, 1.25, 1.299, 1.391, 1.436, 1.506, 1.608, 1.745, 1.808, 2.107, 2.15]
J2_lowT_c2c3starMax =  [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017, 0.018, 0.019, 0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.05, 0.055, 0.06, 0.065, 0.07, 0.075, 0.08, 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.1, 0.1025, 0.105, 0.1075]
lowT_c2c3starMax =  [0.013, 0.026, 0.04, 0.052, 0.066, 0.078, 0.091, 0.105, 0.118, 0.13, 0.144, 0.157, 0.169, 0.183, 0.196, 0.208, 0.223, 0.236, 0.248, 0.261, 0.326, 0.391, 0.458, 0.526, 0.588, 0.656, 0.726, 0.793, 0.876, 0.962, 1.028, 1.142, 1.229, 1.285, 1.364, 1.409, 1.476, 1.568, 1.698, 1.765, 2.016, 2.027]


J2_highT_c2c3star =  [0.065, 0.07, 0.075, 0.08, 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.
J2Min_c3starexpc3star=  [0.0001, 0.00015, 0.00018, 0.000156, 0.000163, 0.000181, 0.000196, 0.000213, 0.000235, 0.000251, 0.000274, 0.000302, 0.000333, 0.000364, 0.000396, 0.000428, 0.000479, 0.000517, 0.000571, 0.000622, 0.000668, 0.000732, 0.000815, 0.000924, 0.000985, 0.001089, 0.001172, 0.001272, 0.001397, 0.001518, 0.001672, 0.001801, 0.001954, 0.002155, 0.002359, 0.002562, 0.002774, 0.003017, 0.003311, 0.003601, 0.003902, 0.004327, 0.00469, 0.005097, 0.005557, 0.006048, 0.006575, 0.007331, 0.007859, 0.008514, 0.009431, 0.010121, 0.011158, 0.012383, 0.013545, 0.014479, 0.015822, 0.017339, 0.019306, 0.020593, 0.022607, 0.024164, 0.02653, 0.028316, 0.03089, 0.032705, 0.03399, 0.035108, 0.036237, 0.037553, 0.037948, 0.036391, 0.03336, 0.030879, 0.026413, 0.022712, 0.016032, 0.004482, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001]
J2Max_c3starexpc3star=  [0.000236, 0.000259, 0.000286, 0.000312, 0.00033, 0.00036, 0.000386, 0.000415, 0.000452, 0.000482, 0.000522, 0.000573, 0.000625, 0.000679, 0.000739, 0.00085, 0.000931, 0.001003, 0.0011, 0.001192, 0.001303, 0.001415, 0.00154, 0.001686, 0.001855, 0.002013, 0.002199, 0.002382, 0.002583, 0.002792, 0.003131, 0.003372, 0.003711, 0.004015, 0.004438, 0.004791, 0.005271, 0.005671, 0.006263, 0.006877, 0.007465, 0.008097, 0.008773, 0.009651, 0.010563, 0.011472, 0.012586, 0.013586, 0.014768, 0.016247, 0.017781, 0.019407, 0.021216, 0.023066, 0.025162, 0.027463, 0.030142, 0.032592, 0.0353, 0.038743, 0.042548, 0.046398, 0.049864, 0.054067, 0.059385, 0.063786, 0.06834, 0.074167, 0.078715, 0.083749, 0.089057, 0.095645, 0.099887, 0.104947, 0.111498, 0.116507, 0.123124, 0.128805, 0.13, 0.13, 0.13, 0.13, 0.13, 0.13, 0.13, 0.13, 0.13, 0.13, 0.13, 0.13, 0.13, 0.13]

# %%
plt.figure(figsize=(4,3),dpi = 300)
margin = [0.15, 0.15,0.05, 0.25]
ms = 2
plt.axes(margin[:2] + [1-margin[0]-margin[2], 1-margin[1]-margin[3]])
#plt.grid(which = 'both', alpha = 0.4, linestyle = '--')

# c2 - c3 *
plt.plot(T_c2c3star, J2_c2c3star,  'v', color = '#EB531B',alpha = 0.8,
         label = r' $c_{2} = c_{3 \star}$', markersize = ms+1)#+'\n ($T$ scan)')
#
plt.plot(lowT_c2c3starMin, J2_lowT_c2c3starMin,  '>', color = '#EB531B', alpha = 0.2, markersize = ms)
plt.plot(lowT_c2c3starMax, J2_lowT_c2c3starMax,  '>', color = '#EB531B', alpha = 0.2, markersize = ms)

##c1
plt.fill_betweenx(J2c1expc1,TMin_c1expc1, TMax_c1expc1,linewidth = 0.0, color = '#1f77b4',alpha = 0.4,
         label = r'$c_1$', hatch = '.....')
plt.plot(TMin_c1expc1,J2c1expc1, '.', color = '#1f77b4', markersize = ms,alpha = 0.2)
plt.plot(TMax_c1expc1,J2c1expc1, '.', color = '#1f77b4', markersize = ms,alpha = 0.2)


##c2
#
TmaxList = [min(TMax_c2expc2[j], max( TMin_c2expc2)) for j in range(len(TMax_c2expc2))]
plt.fill_betweenx(J2c2expc2, TMin_c2expc2, TmaxList, 
                  color = '#ff7f0e',alpha = 0.2,linewidth = 0.0)
plt.plot(TMin_c2expc2,J2c2expc2, 'x', color = '#ff7f0e', markersize = ms, alpha = 0.2)
m = 32
plt.plot(TmaxList[1:m],J2c2expc2[1:m], 'x', color = '#ff7f0e', markersize = ms,alpha = 0.2)

TminList = [max(HT_TMin_c2expc2[j], max(TMin_c2expc2)) 
            for j in range(len(TMax_c2expc2))]
plt.fill_betweenx(HT_J2c2expc2, TminList , HT_TMax_c2expc2,
                  color = '#ff7f0e',alpha = 0.2,linewidth = 0.0)
m = 30
plt.plot(TminList[:m], HT_J2c2expc2[:m],'x',color = '#ff7f0e',markersize = ms,alpha = 0.2)
plt.plot(HT_TMax_c2expc2, HT_J2c2expc2,'x',color = '#ff7f0e',markersize = ms,alpha = 0.2)
#
#
plt.fill_between(Tc2expc2, J2Min_c2expc2, J2Max_c2expc2,
                 color = '#ff7f0e',alpha = 0.2,linewidth = 0.0,
         label = r'$c_2$',
                hatch = 'xxxxxx')
plt.plot(Tc2expc2,J2Min_c2expc2,'x',color = '#ff7f0e', markersize = ms, alpha = 0.5)
plt.plot(Tc2expc2,J2Max_c2expc2,'x',color = '#ff7f0e', markersize = ms, alpha = 0.5)

#c3par

plt.fill_between(Tc3parexpc3par, J2Min_c3parexpc3par, 
                 J2Max_c3parexpc3par, color = '#2ca02c',alpha = 0.2,linewidth = 0.0)
plt.fill_betweenx(J2c3parexpc3par, TMin_c3parexpc3par, TMax_c3parexpc3par,
                  color = '#2ca02c',alpha = 0.2,linewidth = 0.0, label = r'$c_{3||}$')
plt.plot(TMin_c3parexpc3par, J2c3parexpc3par,'v',color = '#2ca02c',markersize = ms/2,alpha = 0.4)
plt.plot(TMax_c3parexpc3par, J2c3parexpc3par,'v',color = '#2ca02c',markersize = ms/2,alpha = 0.4)

#c3star
plt.fill_between(Tc3starexpc3star, J2Min_c3starexpc3star, 
                 J2Max_c3starexpc3star, color = '#d62728',alpha = 0.1, linewidth =0.0,label = r'$c_{3\star}$' )
plt.plot(Tc3starexpc3star,J2Min_c3starexpc3star,'*',color = '#d62728',markersize = ms,mew = 0.1,alpha = 0.2)
plt.plot(Tc3starexpc3star,J2Max_c3starexpc3star,'*',color = '#d62728',markersize = ms,mew = 0.1,alpha = 0.2)


# c2 - c3 //
plt.plot( lowT_c2c3parMin, J2_lowT_c2c3parMin,'<', color = '#AB8C1A', alpha = 0.2, markersize = ms)
plt.plot(lowT_c2c3parMax,J2_lowT_c2c3parMax,  '<', color = '#AB8C1A', alpha = 0.2, markersize = ms)

###plt.plot(highT_c2c3parMin, J2_highT_c2c3parMin, '<', color = '#AB8C1A', alpha = 0.2, markersize = ms)
###plt.plot(highT_c2c3parMax, J2_highT_c2c3parMax,  '<', color = '#AB8C1A', alpha = 0.2, markersize = ms)

plt.plot(T_c2c3par, J2_c2c3par,  '^', color = '#AB8C1A',alpha = 0.8,
         label = r'$c_{2} = c_{3 ||}$', markersize = ms+1)#+'\n ($T$ scan)')
plt.fill_between(T_c2c3par,[0 for i in range(len(T_c2c3par))],
                 J2_c2c3par, color = '#AB8C1A', linewidth=0.0,
                 alpha = 0.5, label = r'$c_2 > c_{3||}$')
plt.legend(loc='upper left', bbox_to_anchor= (0, 1), ncol=2,
          frameon = False)
#plt.xticks(np.arange(0, 5.75, 0.5))
plt.yticks(np.arange(0, 0.13, 0.01))
plt.xlim([1e-2,5])
plt.ylim([0, 0.12])
plt.xlabel(r'$T/J_1$')
plt.ylabel(r'$J_2/J_1$')
plt.xscale('log')
plt.xticks([1e-2, 5e-2, 1e-1, 5e-1, 1, 5])
plt.savefig("Bounds_FullPicture_LargeErrors.png")
plt.savefig("Bounds_FullPicture_LargeErrors.pdf")
plt.savefig("Bounds_FullPicture_LargeErrors.svg")

# %%
###c3star
##plt.fill_between(Tc3starexpc3star, J2Min_c3starexpc3star, 
##                 J2Max_c3starexpc3star, color = '#d62728',alpha = 0.05, linewidth =0.0)
#
#
TMaxSet = set(TMax_c3starexpc3star)
TMaxSet.remove(max(TMaxSet))
Tlimc3star = max(TMaxSet)
TmaxList = [min(TMax_c3starexpc3star[j], Tlimc3star) 
            for j in range(len(J2c3starexpc3star)) if J2c3starexpc3star[j]<0.08]
TminList = [min(TMin_c3starexpc3star[j], Tlimc3star) 
            for j in range(len(J2c3starexpc3star)) if J2c3starexpc3star[j]<0.08]
#
J2c3starexpc3star = np.array(J2c3starexpc3star)
##
plt.fill_betweenx(J2c3starexpc3star[0:len(TmaxList)], TminList, 
                  TmaxList,
                  color = '#d62728',linewidth = 0.0,alpha = 0.05,label = r'$c_{3\star}$')
plt.fill_betweenx(MT_J2c3starexpc3star, MT_TMin_c3starexpc3star, 
                  MT_TMax_c3starexpc3star,
                  color = '#d62728',alpha = 0.05,linewidth = 0.0)
TminList =  [max(HT_TMin_c3starexpc3star[j], Tlimc3star+0.005)
             for j in range(len(HT_TMin_c3starexpc3star))]
plt.fill_betweenx(HT_J2c3starexpc3star, TminList, 
                  HT_TMax_c3starexpc3star,
                  color = '#d62728',alpha = 0.05,linewidth = 0.0)
#TminList =  [max(HT2_TMin_c3starexpc3star[j], max(TMin_c3starexpc3star))
#             for j in range(len(HT2_TMin_c3starexpc3star))]
#
