 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.1, 0.1025, 0.105, 0.1075]
highT_c2c3star =  [11.94, 9.588, 8.44, 7.472, 6.952, 6.54, 6.184, 5.778, 5.786, 5.029, 4.825, 4.681, 4.104, 3.587]
J2_highT_c2c3starMin =  [0.06, 0.065, 0.07, 0.075, 0.08, 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.1, 0.1025, 0.105, 0.1075]
highT_c2c3starMin =  [12.194, 10.556, 8.759, 8.099, 7.3, 6.683, 6.475, 5.862, 5.622, 5.387, 5.168, 4.79, 4.121, 3.912, 3.39]
J2_highT_c2c3starMax =  [0.065, 0.07, 0.075, 0.08, 0.085, 0.0875, 0.09, 0.0925, 0.095, 0.0975, 0.1, 0.1025, 0.105, 0.1075, 0.11]
highT_c2c3starMax =  [12.381, 12.352, 9.45, 8.539, 7.715, 7.109, 6.606, 5.842, 5.832, 5.21, 5.168, 4.722, 4.166, 3.806, 3.325]

# %%
diff = sorted(list(set(J2_lowT_c2c3star)-set(J2_highT_c2c3star)))
diff2 = sorted([diff[len(diff)-1]]+list(set(J2_highT_c2c3star)-set(diff)))

# %%
plt.figure(figsize=(7,5),dpi = 300)
plt.fill_between( [0,.20], [3, 3], [7, 7],color = 'green', alpha = 0.1,
                 label = 'Possible experimental temperature range \n from the ratio of frustrated triangles')
plt.plot(J2_lowT_c2c3par, lowT_c2c3par, 'v', color = '#AB8C1A',
         label = r'Minimal crossing temperature - $c_{2}$ and $c_{3 ||}$')
plt.plot(J2_lowT_c2c3parMin, lowT_c2c3parMin, 'v', color = '#AB8C1A', alpha = 0.3,
         label = r' Errors on minimal crossing temperature - $c_{2}$ and $c_{3 ||}$')
plt.plot(J2_lowT_c2c3parMax, lowT_c2c3parMax, 'v', color = '#AB8C1A', alpha = 0.3)
plt.plot(J2_highT_c2c3par, highT_c2c3par, '^', color = '#AB8C1A',
         label = r'Maximal crossing temperature - $c_{2}$ and $c_{3 ||}$')
plt.plot(J2_highT_c2c3parMin, highT_c2c3parMin, '^', color = '#AB8C1A', alpha = 0.3,
         label = r' Errors on maximal crossing temperature - $c_{2}$ and $c_{3 ||}$')
plt.plot(J2_highT_c2c3parMax, highT_c2c3parMax, '^', color = '#AB8C1A', alpha = 0.3)
plt.fill_between(J2_lowT_c2c3par, lowT_c2c3par, highT_c2c3parMin, color = '#AB8C1A', alpha = 0.2)
#
plt.plot(J2_lowT_c2c3star, lowT_c2c3star, '^', color ='#EB531B',
         label = r'Minimal crossing temperature - $c_{2}$ and $c_{3 \star}$')
plt.plot(J2_lowT_c2c3starMin, lowT_c2c3starMin, '^', color = '#EB531B',
         alpha = 0.5, label = r' Errors on minimal crossing temperature - $c_{2}$ and $c_{3 \star}$')
plt.plot(J2_lowT_c2c3starMax, lowT_c2c3starMax, '^', color = '#EB531B', alpha = 0.3)
plt.plot(J2_highT_c2c3star, highT_c2c3star, 'v', color = '#EB531B', 
         label = r'Maximal crossing temperature - $c_{2}$ and $c_{3 \star}$')
plt.plot(J2_highT_c2c3starMin, highT_c2c3starMin, 'v', color = '#EB531B', alpha = 0.3, 
         label = r' Errors on maximal crossing temperature - $c_{2}$ and $c_{3 \star}$')
plt.plot(J2_highT_c2c3starMax, highT_c2c3starMax, 'v', color = '#EB531B', alpha = 0.3)
plt.fill_between(diff,np.array(lowT_c2c3star)[0:len(diff)], [12.5 for i in range(len(diff))], 
                 color = '#EB531B', alpha = 0.1)
plt.fill_between(diff2,np.array(lowT_c2c3star)[len(diff)-1:],[12.5]+highT_c2c3star, 
                 color = '#EB531B', alpha = 0.1)
plt.xlabel(r'$J_2/J_1}$')
plt.grid(which = 'both')
plt.legend(loc='lower left', bbox_to_anchor= (0.7, 0.0), ncol=1)
plt.xlim([0, None])
plt.ylim([0, None])
plt.ylabel(r'$T/J_1}$')
plt.savefig("Bounds.png")

# %%
plt.figure(figsize=(7,5),dpi = 300)
plt.fill_betweenx( [0,.20], [3, 3], [7, 7],color = 'green', alpha = 0.1,
                 label = 'Possible experimental temperature range \n from the ratio of frustrated triangles')
plt.plot(lowT_c2c3par, J2_lowT_c2c3par,  '<', color = '#AB8C1A',
         label = r'Minimal crossing temperature - $c_{2}$ and $c_{3 ||}$')
plt.plot( lowT_c2c3parMin, J2_lowT_c2c3parMin,'<', color = '#AB8C1A', alpha = 0.3,
         label = r' Errors on minimal crossing temperature - $c_{2}$ and $c_{3 ||}$')
plt.plot(lowT_c2c3parMax,J2_lowT_c2c3parMax,  '<', color = '#AB8C1A', alpha = 0.3)
plt.plot(highT_c2c3par, J2_highT_c2c3par,  '>', color = '#AB8C1A',
         label = r'Maximal crossing temperature - $c_{2}$ and $c_{3 ||}$')
plt.plot(highT_c2c3parMin, J2_highT_c2c3parMin, '>', color = '#AB8C1A', alpha = 0.3,
         label = r' Errors on maximal crossing temperature - $c_{2}$ and $c_{3 ||}$')
plt.plot(highT_c2c3parMax, J2_highT_c2c3parMax,  '>', color = '#AB8C1A', alpha = 0.3)

plt.fill_between(lowT_c2c3parMax,[0 for i in range(len(lowT_c2c3parMax))],
                 J2_lowT_c2c3parMax, color = '#AB8C1A', linewidth=0.0,
                 alpha = 0.2, label = r"$c_2 > c_{3||}$")
plt.fill_between([lowT_c2c3parMax[-1], highT_c2c3par[-1]],
                 [0, 0],
                 [J2_lowT_c2c3parMax[-1], J2_highT_c2c3par[-1]], 
                 color = '#AB8C1A', linewidth=0.0,
                 alpha = 0.2)
plt.fill_between(highT_c2c3par, [0 for i in range(len(highT_c2c3par))],
                 J2_highT_c2c3par,color = '#AB8C1A', linewidth=0.0, 
                 alpha = 0.2)

plt.plot(lowT_c2c3star, J2_lowT_c2c3star,  '>', color ='#EB531B',
         label = r'Minimal crossing temperature - $c_{2}$ and $c_{3 \star}$')
plt.plot(lowT_c2c3starMin, J2_lowT_c2c3starMin,  '>', color = '#EB531B',
         alpha = 0.5, label = r' Errors on minimal crossing temperature - $c_{2}$ and $c_{3 \star}$')
plt.plot(lowT_c2c3starMax, J2_lowT_c2c3starMax,  '>', color = '#EB531B', alpha = 0.3)
plt.plot(highT_c2c3star, J2_highT_c2c3star,'<', color = '#EB531B', 
         label = r'Maximal crossing temperature - $c_{2}$ and $c_{3 \star}$')
plt.plot(highT_c2c3starMin,J2_highT_c2c3starMin,  '<', color = '#EB531B', alpha = 0.3, 
         label = r' Errors on maximal crossing temperature - $c_{2}$ and $c_{3 \star}$')
plt.plot(highT_c2c3starMax, J2_highT_c2c3starMax,  '<', color = '#EB531B', alpha = 0.3)
#plt.fill_between(diff,np.array(lowT_c2c3star)[0:len(diff)], [12.5 for i in range(len(diff))], 
#                 color = '#EB531B', alpha = 0.1)
#plt.fill_between(diff2,np.array(lowT_c2c3star)[len(diff)-1:],[12.5]+highT_c2c3star, 
#                 color = '#EB531B', alpha = 0.1)
plt.fill_between(lowT_c2c3star,[0 for i in range(len(lowT_c2c3star))],
                 J2_lowT_c2c3star, color = '#EB531B', linewidth=0.0,
                 alpha = 0.1, label = r"$c_2 > c_{3\star}$")
plt.fill_between([lowT_c2c3star[-1], highT_c2c3star[-1]],
                 [0, 0],
                 [J2_lowT_c2c3star[-1], J2_highT_c2c3star[-1]], 
                 color = '#EB531B', linewidth=0.0,
                 alpha = 0.1)
plt.fill_between(highT_c2c3star, [0 for i in range(len(highT_c2c3star))],
                 J2_highT_c2c3star,color = '#EB531B', linewidth=0.0, 
                 alpha = 0.1)

plt.grid(which = 'both')
plt.legend(loc='lower left', bbox_to_anchor= (-0.2, 1.0), ncol=2)
plt.xlim([0, 12])
plt.ylim([0, 0.2])
plt.xlabel(r'$T/J_1}$')
plt.ylabel(r'$J_2/J_1}$')
plt.savefig("Bounds_FromJ2")

# %%
T_c2c3par =  [0.1938, 0.2, 0.2992, 0.3984, 0.4977, 0.5969, 0.6961, 0.7953, 0.8945, 0.9938, 1.093, 1.1922, 1.2914, 1.3906, 1.4898, 1.5891, 1.6883, 1.7875, 1.8867, 1.9859, 2.0852, 2.1844, 2.2836, 2.3828, 2.482, 2.5813, 2.6805, 2.7797, 2.8789, 2.9781, 3.0773, 3.1766, 3.2758, 3.375, 3.4742, 3.5734, 3.6727, 3.7719, 3.8711, 3.9703, 4.0695, 4.1688, 4.268, 4.3672, 4.4664, 4.5656, 4.6648, 4.7641, 4.8633, 4.9625, 5.0617, 5.1609, 5.2602, 5.3594, 5.4586, 5.8555, 5.9547, 6.0539, 6.1531, 6.2523, 6.3516, 6.6492, 6.7484, 7.0461, 7.1453, 8.0383, 8.1375, 8.9312, 9.2289, 9.3281, 10.0227, 10.5188, 10.618, 10.7172, 10.8164, 10.9156, 11.0148, 11.1141, 11.2133, 11.5109, 11.6102, 11.7094, 11.8086, 12.1063, 12.6023]
J2_c2c3par =  [0.002, 0.002456, 0.003484, 0.004572, 0.005559, 0.006578, 0.00755, 0.008452, 0.009077, 0.009507, 0.009936, 0.010597, 0.010728, 0.010577, 0.010707, 0.010738, 0.010373, 0.010079, 0.01035, 0.010392, 0.010049, 0.010209, 0.009684, 0.009123, 0.008554, 0.008343, 0.00892, 0.007869, 0.00707, 0.007556, 0.007229, 0.005888, 0.006566, 0.0065, 0.006109, 0.005516,
T_c2c3starMax =  [0.0032, 0.0064, 0.0095, 0.0126, 0.0157, 0.0189, 0.022, 0.0251, 0.0282, 0.0314, 0.0345, 0.0376, 0.0407, 0.0438, 0.047, 0.0501, 0.0532, 0.0563, 0.0595, 0.0626, 0.0657, 0.0688, 0.072, 0.0751, 0.0782, 0.0813, 0.0844, 0.0876, 0.0907, 0.0938, 0.0969, 0.1001, 0.1032, 0.1063, 0.1094, 0.1126, 0.1157, 0.1188, 0.1219, 0.125, 0.1282, 0.1313, 0.1344, 0.1375, 0.1407, 0.1438, 0.1469, 0.15, 0.1532, 0.1563, 0.1594, 0.1625, 0.1656, 0.1688, 0.1719, 0.175, 0.1781, 0.1813, 0.1844, 0.1875, 0.1906, 0.1938, 0.1969, 0.2, 0.2992, 0.3984, 0.4977, 0.5969, 0.6961, 0.7953, 0.8945, 0.9938, 1.093, 1.1922, 1.2914, 1.3906, 1.4898, 1.5891, 1.6883, 1.7875]
J2_c2c3starMax =  [0.000383, 0.000662, 0.00094, 0.001217, 0.001471, 0.001779, 0.002046, 0.002315, 0.002624, 0.002893, 0.003142, 0.00342, 0.003707, 0.003985, 0.004199, 0.004472, 0.004822, 0.005075, 0.0053, 0.005563, 0.005844, 0.006187, 0.006463, 0.006704, 0.006906, 0.007242, 0.007484, 0.00776, 0.007994, 0.008297, 0.008617, 0.008784, 0.009124, 0.00935, 0.009647, 0.009973, 0.010195, 0.010426, 0.010773, 0.011071, 0.011274, 0.011554, 0.011825, 0.012075, 0.012424, 0.012655, 0.013, 0.01316, 0.013467, 0.013758, 0.014045, 0.014257, 0.014588, 0.01477, 0.014921, 0.015401, 0.015666, 0.015863, 0.016133, 0.016636, 0.016823, 0.016948, 0.01723, 0.020722, 0.029666, 0.038412, 0.046974, 0.056484, 0.064221, 0.072119, 0.079717, 0.085965, 0.093092, 0.097587, 0.104053, 0.108721, 0.113008, 0.116579, 0.120793, 0.123457]

# %%
plt.figure(figsize=(7,5),dpi = 300)
plt.fill_betweenx( [0,.20], [3, 3], [7, 7],color = 'green', alpha = 0.1,
                 label = 'Possible experimental temperature range \n from the ratio of frustrated triangles')
plt.plot(T_c2c3par, J2_c2c3par,  '^', color = '#AB8C1A',
         label = r'Minimal crossing $J_2$ - $c_{2}$ and $c_{3 ||}$')

plt.fill_between(T_c2c3par,[0 for i in range(len(T_c2c3par))],
                 J2_c2c3par, color = '#AB8C1A', linewidth=0.0,
                 alpha = 0.1, label = r"$c_2 > c_{3||}$")
plt.plot(T_c2c3parMin, J2_c2c3parMin,'^', color = '#AB8C1A', alpha = 0.3,
         label = r' Errors on minimal crossing $J_2$  - $c_{2}$ and $c_{3 ||}$')
plt.plot(T_c2c3parMax,J2_c2c3parMax,  '^', color = '#AB8C1A', alpha = 0.3)

plt.plot(T_c2c3star, J2_c2c3star,  'v', color = '#EB531B',
         label = r'Minimal crossing $J_2$ - $c_{2}$ and $c_{3 \star}$')

plt.fill_between(T_c2c3star,[0 for i in range(len(T_c2c3star))],
                 J2_c2c3star, color = '#EB531B', linewidth=0.0,
                 alpha = 0.1, label = r"$c_2 > c_{3\star}$")
plt.plot(T_c2c3starMin, J2_c2c3starMin,'v', color = '#EB531B', alpha = 0.3,
         label = r' Errors on minimal crossing $J_2$  - $c_{2}$ and $c_{3 \star}$')
plt.plot(T_c2c3starMax,J2_c2c3starMax,  'v', color = '#EB531B', alpha = 0.3)


plt.grid(which = 'both')
plt.legend(loc='lower left', bbox_to_anchor= (-0.2, 1.0), ncol=2)
plt.xlim([0, 12])
plt.ylim([0, 0.2])
plt.xlabel(r'$T/J_1}$')
plt.ylabel(r'$J_2/J_1}$')
plt.savefig("Bounds_FromT")

# %%
### FULL PICTURE ###

# %%
Tc1expc1 =  [2.8789, 2.9781, 3.0773, 3.1766]
J2Min_c1expc1=  [0.062284, 0.0001, 0.0001, 0.0001]
J2Max_c1expc1=  [0.13, 0.13, 0.087562, 0.01901]

# %%
Tc2expc2 =  [0.0032, 0.0064, 0.0095, 0.0126, 0.0157, 0.0189, 0.022, 0.0251, 0.0282, 0.0314, 0.0345, 0.0376, 0.0407, 0.0438, 0.047, 0.0501, 0.0532, 0.0563, 0.0595, 0.0626, 0.0657, 0.0688, 0.072, 0.0751, 0.0782, 0.0813, 0.0844, 0.0876, 0.0907, 0.0938, 0.0969, 0.1001, 0.1032, 0.1063, 0.1094, 0.1126, 0.1157, 0.1188, 0.1219, 0.125, 0.1282, 0.1313, 0.1344, 0.1375, 0.1407, 0.1438, 0.1469, 0.15, 0.1532, 0.1563, 0.1594, 0.1625, 0.1656, 0.1688, 0.1719, 0.175, 0.1781, 0.1813, 0.1844, 0.1875, 0.1906, 0.1938, 0.1969, 0.2, 0.2992, 0.3984, 0.4977, 0.5969, 0.6961, 0.7953, 0.8945, 0.9938, 1.093, 1.1922, 1.2914, 1.3906, 1.4898, 1.5891, 1.6883, 1.7875, 1.8867, 1.9859, 2.0852, 2.1844, 2.2836, 2.3828, 2.482, 2.5813, 2.6805, 2.7797, 2.8789, 2.9781, 3.0773, 3.1766, 3.2758, 3.375, 3.4742, 3.5734, 3.6727, 3.7719, 3.8711, 3.9703, 4.0695, 4.1688, 4.268, 4.3672, 4.4664, 4.5656, 4.6648, 4.7641, 4.8633, 4.9625, 5.0617, 5.1609, 5.2602, 5.3594, 5.4586, 5.5578, 5.657]
J2Min_c2expc2=  [0.000373, 0.000623, 0.00088, 0.001137, 0.001389, 0.00164, 0.001883, 0.002137, 0.002388, 0.002633, 0.002885, 0.003141, 0.003391, 0.003635, 0.003888, 0.004142, 0.0044, 0.004646, 0.004891, 0.005141, 0.005385, 0.005642, 0.00589, 0.006131, 0.00638, 0.006671, 0.006917, 0.007162, 0.007415, 0.00763, 0.00787, 0.00
, 0.0069, 0.007045, 0.007184, 0.007334, 0.00751, 0.007677, 0.007826, 0.007997, 0.008119, 0.008271, 0.008503, 0.008647, 0.008752, 0.008915, 0.009101, 0.009256, 0.009417, 0.009586, 0.00968, 0.009842, 0.009978, 0.012031, 0.01735, 0.022487, 0.02737, 0.032356, 0.036942, 0.041173, 0.045416, 0.048733, 0.051976, 0.054806, 0.056884, 0.058227, 0.059196, 0.060127, 0.06091, 0.061045, 0.060971, 0.060561, 0.059844, 0.058803, 0.058007, 0.057286, 0.056112, 0.055021, 0.053491, 0.051522, 0.049285, 0.048041, 0.046927, 0.045366, 0.042167, 0.039577, 0.037487, 0.035511, 0.034263, 0.032854, 0.030869, 0.025554, 0.02416, 0.021636, 0.020976, 0.016751, 0.015257, 0.011138, 0.009093, 0.008974, 0.00252, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001]
J2Max_c3starexpc3star=  [0.000241, 0.000423, 0.000599, 0.000779, 0.001012, 0.001151, 0.001338, 0.001521, 0.001699, 0.001889, 0.002098, 0.002277, 0.002446, 0.002611, 0.002805, 0.002999, 0.003164, 0.003354, 0.003551, 0.003716, 0.003891, 0.00407, 0.004244, 0.004411, 0.004604, 0.004794, 0.004959, 0.005149, 0.005337, 0.005507, 0.005679, 0.005871, 0.006073, 0.006242, 0.006399, 0.006593, 0.00677, 0.006949, 0.007137, 0.0073, 0.00748, 0.007675, 0.007883, 0.008059, 0.008223, 0.0084, 0.008569, 0.008737, 0.008917, 0.009116, 0.009282, 0.009461, 0.009691, 0.009821, 0.00998, 0.010218, 0.010353, 0.010531, 0.010733, 0.010889, 0.01106, 0.011266, 0.011419, 0.013828, 0.019724, 0.025652, 0.031296, 0.036917, 0.042232, 0.047432, 0.052103, 0.05646, 0.060087, 0.063892, 0.067153, 0.069827, 0.071938, 0.073818, 0.0749, 0.076762, 0.077629, 0.078093, 0.078945, 0.07957, 0.080173, 0.080921, 0.081266, 0.081302, 0.081131, 0.08071, 0.080801, 0.081252, 0.081211, 0.081034, 0.081182, 0.080659, 0.079106, 0.079116, 0.079558, 0.078956, 0.078952, 0.080332, 0.079503, 0.078217, 0.078064, 0.080614, 0.080912, 0.079506, 0.078829, 0.078758, 0.080056, 0.078525, 0.078416, 0.078209, 0.076434, 0.076189, 0.076556, 0.077541, 0.076379]

# %%
plt.figure(figsize=(15,5),dpi = 300)
margin = [0.1, 0.1,0.35, 0.1]

plt.axes(margin[:2] + [1-margin[0]-margin[2], 1-margin[1]-margin[3]])
plt.grid(which = 'both', alpha = 0.4, linestyle = '--')

plt.plot(T_c2c3par, J2_c2c3par,  '^', color = '#AB8C1A',alpha = 0.8,
         label = r'Minimal crossing $J_2$ - $c_{2}$ and $c_{3 ||}$')
plt.plot( lowT_c2c3parMin, J2_lowT_c2c3parMin,'<', color = '#AB8C1A', alpha = 0.2)
plt.plot(lowT_c2c3parMax,J2_lowT_c2c3parMax,  '<', color = '#AB8C1A', alpha = 0.2)
plt.plot(highT_c2c3parMin, J2_highT_c2c3parMin, '<', color = '#AB8C1A', alpha = 0.2,
         label = r' Errors on minimal crossing $J_2$ - $c_{2}$ and $c_{3 ||}$')
plt.plot(highT_c2c3parMax, J2_highT_c2c3parMax,  '<', color = '#AB8C1A', alpha = 0.2)
plt.fill_between(T_c2c3par,[0 for i in range(len(T_c2c3par))],
                 J2_c2c3par, color = '#AB8C1A', linewidth=0.0,
                 alpha = 0.5, label = r"$c_2 > c_{3||}$ (NN physics)")

plt.plot(T_c2c3star, J2_c2c3star,  'v', color = '#EB531B',alpha = 0.8,
         label = r'Minimal crossing $J_2$ - $c_{2}$ and $c_{3 \star}$')

plt.plot(lowT_c2c3starMin, J2_lowT_c2c3starMin,  '>', color = '#EB531B',
         alpha = 0.5)
plt.plot(lowT_c2c3starMax, J2_lowT_c2c3starMax,  '>', color = '#EB531B', alpha = 0.2)
plt.plot(highT_c2c3starMin,J2_highT_c2c3starMin,  '>', color = '#EB531B', alpha = 0.2, 
         label = r' Errors on minimal crossing $J_2$ - $c_{2}$ and $c_{3 \star}$')
plt.plot(highT_c2c3starMax, J2_highT_c2c3starMax,  '>', color = '#EB531B', alpha = 0.2)

#c1
#plt.plot(Tc1expc1, J2Min_c1expc1,  '.', color = '#1f77b4',markersize = 5)
#plt.plot(Tc1expc1, J2Max_c1expc1,  '.', color = '#1f77b4',markersize = 5)

#plt.plot(TMin_c1expc1, J2c1expc1, '.', color = '#1f77b4',markersize = 5)
#plt.plot(TMax_c1expc1, J2c1expc1, '.', color = '#1f77b4',markersize = 5)
plt.fill_betweenx(J2c1expc1,TMin_c1expc1, TMax_c1expc1,linewidth = 0.0, color = '#1f77b4',alpha = 0.2,
         label = r'$c_1$ compatible with the experiment')
#plt.fill_between(Tc1expc1, J2Min_c1expc1, J2Max_c1expc1,linewidth = 0.0, color = '#1f77b4',alpha = 0.2)

#c2

TmaxList = [min(TMax_c2expc2[j], max( TMin_c2expc2)) for j in range(len(TMax_c2expc2))]
#plt.plot(TMin_c2expc2, J2c2expc2, 'x', color = '#ff7f0e',markersize = 5)
#plt.plot(TmaxList, J2c2expc2, 'x', color = '#ff7f0e',markersize = 5)

plt.fill_betweenx(J2c2expc2, TMin_c2expc2, TmaxList, 
                  color = '#ff7f0e',alpha = 0.2,linewidth = 0.0)
plt.fill_between(Tc2expc2, J2Min_c2expc2, J2Max_c2expc2,
                 color = '#ff7f0e',alpha = 0.2,linewidth = 0.0,
         label = r'$c_2$ compatible with the experiment'+'\n lighter area denotes uncertainty')
TminList = [max(HT_TMin_c2expc2[j], max(TMin_c2expc2)) 
            for j in range(len(TMax_c2expc2))]
#plt.plot(TminList, HT_J2c2expc2, 'x', color = '#ff7f0e',markersize = 5)
#plt.plot(HT_TMax_c2expc2, HT_J2c2expc2, 'x', color = '#ff7f0e',markersize = 5)
#
#
#plt.fill_betweenx(HT_J2c2expc2, TminList , HT_TMax_c2expc2,
#                  color = '#ff7f0e',alpha = 0.2,linewidth = 0.0)

#c3par
#plt.plot(Tc3parexpc3par, J2Min_c3parexpc3par, 'v', color = '#2ca02c',markersize = 5)
#plt.plot(Tc3parexpc3par, J2Max_c3parexpc3par, 'v', color = '#2ca02c', markersize = 5)
#plt.plot(TMin_c3parexpc3par, J2c3parexpc3par, 'v', color = '#2ca02c', markersize = 5)
#plt.plot(TMax_c3parexpc3par, J2c3parexpc3par, 'v', color = '#2ca02c', markersize = 5)

plt.fill_between(Tc3parexpc3par, J2Min_c3parexpc3par, 
                 J2Max_c3parexpc3par, color = '#2ca02c',alpha = 0.2,linewidth = 0.0)
plt.fill_betweenx(J2c3parexpc3par, TMin_c3parexpc3par, TMax_c3parexpc3par,
                  color = '#2ca02c',alpha = 0.2,linewidth = 0.0,
         label = r'$c_{3||}$ compatible with the experiment'+'\n lighter area denotes uncertainty')

##c3star
#plt.plot(Tc3starexpc3star, J2Min_c3starexpc3star, '*', color = '#d62728', markersize = 5, alpha = 0.2)
#plt.plot(Tc3starexpc3star, J2Max_c3starexpc3star, '*', color = '#d62728', markersize = 5, alpha = 0.2)
plt.fill_between(Tc3starexpc3star, J2Min_c3starexpc3star, 
                 J2Max_c3starexpc3star, color = '#d62728',alpha = 0.2, linewidth =0.0)


#plt.plot(TMin_c3starexpc3star,J2c3starexpc3star)
#plt.plot(TMax_c3starexpc3star,J2c3starexpc3star)
TmaxList = [min(TMax_c3starexpc3star[j], max(TMin_c3starexpc3star)) 
            for j in range(len(J2c3starexpc3star)) if J2c3starexpc3star[j]<0.08]
J2c3starexpc3star = np.array(J2c3starexpc3star)
#plt.plot(TmaxList, J2c3starexpc3star[0:len(TmaxList)])
#
plt.fill_betweenx(J2c3starexpc3star[0:len(TmaxList)], np.array(TMin_c3starexpc3star)[0:len(TmaxList)], 
                  TmaxList,
                  color = '#d62728',linewidth = 0.0,alpha = 0.2,
                  label = r'$c_{3\star}$ compatible with the experiment'+'\n lighter area denotes uncertainty')
TminList =  [max(HT_TMin_c3starexpc3star[j], max(TMin_c3starexpc3star))
             for j in range(len(HT_TMin_c3starexpc3star))]
#plt.fill_betweenx(HT_J2c3starexpc3star, TminList, 
#                  HT_TMax_c3starexpc3star,
#                  color = '#d62728',alpha = 0.2,linewidth = 0.0)
#TminList =  [max(HT2_TMin_c3starexpc3star[j], max(TMin_c3starexpc3star))
#             for j in range(len(HT2_TMin_c3starexpc3star))]
#plt.fill_betweenx(HT2_J2c3starexpc3star, TminList, 
#                  HT2_TMax_c3starexpc3star,
#                  color = '#d62728',alpha = 0.2,linewidth = 0.0)
plt.legend(loc='upper left', bbox_to_anchor= (1.0, 0.95), ncol=1)
plt.xticks(np.arange(0, 5.75, 0.25))
plt.yticks(np.arange(0, 0.13, 0.01))
plt.xlim([0,5.5])
plt.ylim([0, 0.129])
plt.xlabel(r'$T/J_1}$')
plt.ylabel(r'$J_2/J_1}$')
plt.savefig("Bounds_FullPicture.png")
plt.savefig("Bounds_FullPicture.pdf")
