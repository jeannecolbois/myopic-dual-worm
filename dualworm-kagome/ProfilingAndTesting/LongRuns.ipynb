# %%
import DualwormFunctions as dw
import Observables as obs
# %load_ext line_profiler
# %load_ext memory_profiler
import RunBasis
import argparse
import StartStates as strst
import numpy as np

# %%
nst = 1280;
nsm = 1280;
nips = 10;
nrps = 4;
nb = 16;
measperiod = 1;
nt = 6
nh = 121

# %%
def genArgs():
    parser = argparse.ArgumentParser()
    
    parser.add_argument('-f', type = str)

    parser.add_argument('--L', type = int, default = 12, help = 'Lattice side size')

    # COUPLINGS
    parser.add_argument('--J1', type = float, default = 1,
                        help = 'NN coupling') # nearest-neighbour coupling
    parser.add_argument('--J2', type = float, default = 0,
                        help = '2nd NN coupling') # 2nd NN coupling
    parser.add_argument('--J3', type = float, default = 0,
                        help = '3rd NN coupling') # 3rd NN coupling
    parser.add_argument('--J4', type = float, default = 0.0,
                        help = '4th NN coupling')
    parser.add_argument('--h', type = float, default = 1.0,
                        help = 'Magnetic field')    
    #NUMBER OF STEPS AND ITERATIONS
    parser.add_argument('--nst', type = int, default = nst,
                        help = 'number of thermalisation steps') # number of thermalisation steps
    parser.add_argument('--nsm', type = int, default = nsm,
                        help = 'number of measurements steps') # number of measurement steps
    parser.add_argument('--nips', type = int, default = nips,
                        help = 'number of worm constructions per MC step')
    parser.add_argument('--nrps', type = int, default = nrps,
                        help = 'number of replica loops per MC step')
    parser.add_argument('--measperiod', type = int, default = measperiod,
                        help = 'number of nips worm building + swaps between measurements')
    parser.add_argument('--nb', type = int, default = nb,
                        help = 'number of bins')

    #PARALLELISATION
    parser.add_argument('--ncores', type = int, default = 6,
                        help = 'number of threads to use')

    
    # INITIALISATION PARAMETERS
    parser.add_argument('--randominit', default = False, action ='store_true',
                        help = 'intialise the states randomly')
    parser.add_argument('--same', default = False, action = 'store_true',
                        help = '''initialise all temperatures with the same
                        state (debug purposes)''')
    parser.add_argument('--magninit', default = False, action = 'store_true',
                        help = '''initialise all the temperature with
                        one of the m=1/3 GS''')
    parser.add_argument('--magnstripes', default = False, action = 'store_true',
                       help = '''initialise all the temperature with
                       m=1/3 stripes''')
    parser.add_argument('--maxflip', default = False, action = 'store_true',
                       help = '''initialise all the temperature with
                       maximally flippable plateau''')
    parser.add_argument('--loadfromfile', default = True, action = 'store_true',
                       help = '''initialise all the states with
                       results from a previously performed simulations''')
    parser.add_argument('--filename', type = str, default = 'tests/J1hLongRun_RndInit_AlternateUpdateResults',
                       help = '''initialise all the states with
                       results from a previously performed simulations''')
    
    #WORM PARAMETERS
    parser.add_argument('--nmaxiter', type = int, default = 10,
                        help = '''maximal number of segments in a loop update over the
                        size of the lattice (1 = 1times the number of dualbonds in the
                        lattice)''')
    parser.add_argument('--measupdate', default = False, action = 'store_true',
                       help = '''activate to mimic the action of the measuring tip''')
    parser.add_argument('--p', type = float, default = 0.0, 
                       help = '''prob of the measuring tip flipping the spin (number between 0 and 1)''')
    parser.add_argument('--ssf', default = True, action = 'store_true',
                        help = 'activate for single spin flip update')
    parser.add_argument('--alternate', default = True, action = 'store_true',
                        help = 'activate for single spin flip update and dw update')
    parser.add_argument('--checkgs', default = True, action = 'store_true',
                        help = 'activate to debug ssf')
    
    #TEMPERATURE PARAMETERS
    parser.add_argument('--t_list', nargs = '+', type = float, default = [0.05,0.3],
                        help = 'list of limiting temperature values')
    parser.add_argument('--nt_list', nargs = '+', type = int, default = [nt],
                        help = 'list of number of temperatures in between the given limiting temperatures')
    parser.add_argument('--log_tlist', default = False, action='store_true',
                        help = 'state whether you want the temperature be spaced log-like or linear-like (activate if you want log)')
    parser.add_argument('--stat_temps_lims', nargs = '+', type = float,
                        help = '''limiting temperatures for the various ranges of
                        measurements''') 
                        #default will be set to none, and then we can decide what to do later on.
    #MAGNETIC FIELD PARAMETERS
    parser.add_argument('--h_list', nargs = '+', default = [0,6.0],type = float,
                        help = 'list of limiting magnetic field values')
    parser.add_argument('--nh_list', nargs = '+', default = [nh], type = int,
                        help = 'list of number of magnetic fields in between the given limiting temperatures')
    parser.add_argument('--stat_hfields_lims', nargs = '+', type = float,
                help = '''limiting magnetic fields for the various ranges of
                measurements''') 
    #CORRELATIONS PARAMETER
    parser.add_argument('--energy', default = True, action = 'store_true',
                        help = 'activate if you want to save the energy')
    parser.add_argument('--magnetisation', default =True, action = 'store_true',
                        help = 'activate if you want to save the magnetisation')
    parser.add_argument('--charges', default = False, action = 'store_true',
                        help = 'activate if you want to save the charges')
    parser.add_argument('--correlations', default = True, action = 'store_true',
                        help = 'activate if you want to save either central or all correlations')
    parser.add_argument('--all_correlations', default = False, action = 'store_true',
                        help = '''activate if you want to save the correlations for all non-equivalent
                        pairs of sites. Otherwise, will save central correlations.''')
    parser.add_argument('--firstcorrelations', default = False, action = 'store_true',
                        help = 'activate if you want to save first correlations, otherwise will save central')
    #SAVE
    parser.add_argument('--output', type = str, default = "tests/J1hLongRun_RndInit_AlternateUpdate_Measurements", help = 'saving filename (.pkl will be added)')
    args = parser.parse_args()
    return args

# %%
def callRunBasis():
    args = genArgs()
    return RunBasis.main(args)

# %%
# %lprun -f dw.mcs_swaps meanstat, swapst, swapsh, failedupdatesth, failedupdates = callRunBasis()
# Out:
# Lattice side size:  12
# J1  1
# J2  0
# J3  0
# J3st  0
# Couplings extracted
# Hamiltonian expression (without field) computed
# single spin flip update
# alternating ssf and dw update
# Number of temperatures:  6
# Temperatures: [0.05 0.1  0.15 0.2  0.25 0.3 ]
# Number of magnetic fields:  121
# Magnetic fields:  [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15 1.2  1.25 1.3  1.35
#  1.4  1.45 1.5  1.55 1.6  1.65 1.7  1.75 1.8  1.85 1.9  1.95 2.   2.05
#  2.1  2.15 2.2  2.25 2.3  2.35 2.4  2.45 2.5  2.55 2.6  2.65 2.7  2.75
#  2.8  2.85 2.9  2.95 3.   3.05 3.1  3.15 3.2  3.25 3.3  3.35 3.4  3.45
#  3.5  3.55 3.6  3.65 3.7  3.75 3.8  3.85 3.9  3.95 4.   4.05 4.1  4.15
#  4.2  4.25 4.3  4.35 4.4  4.45 4.5  4.55 4.6  4.65 4.7  4.75 4.8  4.85
#  4.9  4.95 5.   5.05 5.1  5.15 5.2  5.25 5.3  5.35 5.4  5.45 5.5  5.55
#  5.6  5.65 5.7  5.75 5.8  5.85 5.9  5.95 6.  ]
# Energies size:  (6, 121)
# [ -864.   -885.6  -907.2  -928.8  -950.4  -972.   -993.6 -1015.2 -1036.8
#  -1058.4 -1080.  -1101.6 -1123.2 -1144.8 -1166.4 -1188.  -1209.6 -1231.2
#  -1252.8 -1274.4 -1296.  -1317.6 -1339.2 -1360.8 -1382.4 -1404.  -1425.6
#  -1447.2 -1468.8 -1490.4 -1512.  -1533.6 -1555.2 -1576.8 -1598.4 -1620.
#  -1641.6 -1663.2 -1684.8 -1706.4 -1728.  -1749.6 -1771.2 -1792.8 -1814.4
#  -1836.  -1857.6 -1879.2 -1900.8 -1922.4 -1944.  -1965.6 -1987.2 -2008.8
#  -2030.4 -2052.  -2073.6 -2095.2 -2116.8 -2138.4 -2160.  -2181.6 -2203.2
#  -2224.8 -2246.4 -2268.  -2289.6 -2311.2 -2332.8 -2354.4 -2376.  -2397.6
#  -2419.2 -2440.8 -2462.4 -2484.  -2505.6 -2527.2 -2548.8 -2570.4     0.
#  -2656.8 -2721.6 -2786.4 -2851.2 -2916.  -2980.8 -3045.6 -3110.4 -3175.2
#  -3240.  -3304.8 -3369.6 -3434.4 -3499.2 -3564.  -3628.8 -3693.6 -3758.4
#  -3823.2 -3888.  -3952.8 -4017.6 -4082.4 -4147.2 -4212.  -4276.8 -4341.6
#  -4406.4 -4471.2 -4536.  -4600.8 -4665.6 -4730.4 -4795.2 -4860.  -4924.8
#  -4989.6 -5054.4 -5119.2 -5184. ]
# RunBasis: Away from gs at t index  0  and h index  1
#    new_en_states[t,h] =  -874.9
#    ref_en_states[h] =  -885.6
# RunBasis: Away from gs at t index  0  and h index  2
#    new_en_states[t,h] =  -905.0
#    ref_en_states[h] =  -907.1999999999999
# RunBasis: Away from gs at t index  0  and h index  6
#    new_en_states[t,h] =  -989.4
#    ref_en_states[h] =  -993.5999999999999
# RunBasis: Away from gs at t index  0  and h index  7
#    new_en_states[t,h] =  -1014.5
#    ref_en_states[h] =  -1015.2
# RunBasis: Away from gs at t index  0  and h index  8
#    new_en_states[t,h] =  -995.2
#    ref_en_states[h] =  -1036.8
# RunBasis: Away from gs at t index  0  and h index  10
#    new_en_states[t,h] =  -1018.0
#    ref_en_states[h] =  -1080.0
# RunBasis: Away from gs at t index  0  and h index  14
#    new_en_states[t,h] =  -1159.4
#    ref_en_states[h] =  -1166.3999999999999
# RunBasis: Away from gs at t index  0  and h index  15
#    new_en_states[t,h] =  -1128.0
#    ref_en_states[h] =  -1188.0
# RunBasis: Away from gs at t index  0  and h index  16
#    new_en_states[t,h] =  -1065.6
#    ref_en_states[h] =  -1209.6
# RunBasis: Away from gs at t index  0  and h index  17
#    new_en_states[t,h] =  -1215.9
#    ref_en_states[h] =  -1231.2
# RunBasis: Away from gs at t index  0  and h index  18
#    new_en_states[t,h] =  -1242.0
#    ref_en_states[h] =  -1252.8
# RunBasis: Away from gs at t index  0  and h index  19
#    new_en_states[t,h] =  -1272.5
#    ref_en_states[h] =  -1274.3999999999999
# RunBasis: Away from gs at t index  0  and h index  20
#    new_en_states[t,h] =  -1284.0
#    ref_en_states[h] =  -1296.0
# RunBasis: Away from gs at t index  0  and h index  21
#    new_en_states[t,h] =  -1281.9
#    ref_en_states[h] =  -1317.6
# RunBasis: Away from gs at t index  0  and h index  26
#    new_en_states[t,h] =  -866.6
#    ref_en_states[h] =  -1425.6000000000001
# RunBasis: Away from gs at t index  0  and h index  28
#    new_en_states[t,h] =  -1443.6
#    ref_en_states[h] =  -1468.8
# RunBasis: Away from gs at t index  0  and h index  34
#    new_en_states[t,h] =  -1584.6
#    ref_en_states[h] =  -1598.4
# RunBasis: Away from gs at t index  0  and h index  39
#    new_en_states[t,h] =  -1702.5
#    ref_en_states[h] =  -1706.4
# RunBasis: Away from gs at t index  0  and h index  42
#    new_en_states[t,h] =  -1762.8000000000002
#    ref_en_states[h] =  -1771.2
# RunBasis: Away from gs at t index  0  and h index  43
#    new_en_states[t,h] =  -1775.6
#    ref_en_states[h] =  -1792.8
# RunBasis: Away from gs at t index  0  and h index  48
#    new_en_states[t,h] =  -1872.0
#    ref_en_states[h] =  -1900.8000000000002
# RunBasis: Away from gs at t index  0  and h index  56
#    new_en_states[t,h] =  -1996.8000000000002
#    ref_en_states[h] =  -2073.6
# RunBasis: Away from gs at t index  0  and h index  57
#    new_en_states[t,h] =  -2067.6000000000004
#    ref_en_states[h] =  -2095.2
# RunBasis: Away from gs at t index  0  and h index  59
#    new_en_states[t,h] =  -2052.3
#    ref_en_states[h] =  -2138.4
# RunBasis: Away from gs at t index  0  and h index  61
#    new_en_states[t,h] =  -2179.7
#    ref_en_states[h] =  -2181.6
# RunBasis: Away from gs at t index  0  and h index  63
#    new_en_states[t,h] =  -1490.4000000000005
#    ref_en_states[h] =  -2224.8
# RunBasis: Away from gs at t index  0  and h index  64
#    new_en_states[t,h] =  -2219.2
#    ref_en_states[h] =  -2246.4
# RunBasis: Away from gs at t index  0  and h index  65
#    new_en_states[t,h] =  -1852.5
#    ref_en_states[h] =  -2268.0
# RunBasis: Away from gs at t index  0  and h index  66
#    new_en_states[t,h] =  -2285.4
#    ref_en_states[h] =  -2289.6
# RunBasis: Away from gs at t index  0  and h index  68
#    new_en_states[t,h] =  -2076.0000000000005
#    ref_en_states[h] =  -2332.7999999999997
# RunBasis: Away from gs at t index  0  and h index  69
#    new_en_states[t,h] =  -2352.2
#    ref_en_states[h] =  -2354.3999999999996
# RunBasis: Away from gs at t index  0  and h index  70
#    new_en_states[t,h] =  -2368.0
#    ref_en_states[h] =  -2375.9999999999995
# RunBasis: Away from gs at t index  0  and h index  72
#    new_en_states[t,h] =  -2406.4
#    ref_en_states[h] =  -2419.2
# RunBasis: Away from gs at t index  0  and h index  73
#    new_en_states[t,h] =  -2139.1000000000004
#    ref_en_states[h] =  -2440.8
# RunBasis: Away from gs at t index  0  and h index  74
#    new_en_states[t,h] =  -2456.4
#    ref_en_states[h] =  -2462.4
# RunBasis: Away from gs at t index  0  and h index  79
#    new_en_states[t,h] =  -2564.2000000000003
#    ref_en_states[h] =  -2570.4
# RunBasis: Away from gs at t index  0  and h index  80
#    new_en_states[t,h] =  -2592.0
#    ref_en_states[h] =  0.0
# RunBasis: Away from gs at t index  0  and h index  81
#    new_en_states[t,h] =  -2646.0
#    ref_en_states[h] =  -2656.7999999999997
# RunBasis: Away from gs at t index  0  and h index  83
#    new_en_states[t,h] =  -2737.5000000000005
#    ref_en_states[h] =  -2786.4000000000005
# RunBasis: Away from gs at t index  0  and h index  84
#    new_en_states[t,h] =  -2850.8
#    ref_en_states[h] =  -2851.2000000000003
# RunBasis: Away from gs at t index  0  and h index  85
#    new_en_states[t,h] =  -2915.5
#    ref_en_states[h] =  -2916.0
# RunBasis: Away from gs at t index  0  and h index  91
#    new_en_states[t,h] =  -3275.0999999999995
#    ref_en_states[h] =  -3304.7999999999997
# RunBasis: Away from gs at t index  0  and h index  92
#    new_en_states[t,h] =  -2912.4
#    ref_en_states[h] =  -3369.600000000001
# RunBasis: Away from gs at t index  0  and h index  95
#    new_en_states[t,h] =  -3562.5
#    ref_en_states[h] =  -3564.0
# List of measurements to be performed: ['Energy', 'Magnetisation', 'Si', 'Central_Correlations']
# List of field indices to measure: range(0, 121)
# -----------Thermalisation------------------
# Number of thermalisation steps =  1280
# itermcs =  1280
# iterreplicas =  4
# ssf =  True
# alternate =  True
# statsfunctions []
# Time for mcsevolve = 2.0343842959031466
# Time for tempering = 0.034600553289055744
# Time for mapping to spins + computing statistics= 2.416186034679417e-05
# Energies size:  (6, 121)
# Time for all thermalisation steps =  2648.346805334091
# RunBasis: Away from gs at t index  0  and h index  1
#    new_en_states[t,h] =  -875.9
#    ref_en_states[h] =  -885.6
# RunBasis: Away from gs at t index  0  and h index  2
#    new_en_states[t,h] =  -899.8
#    ref_en_states[h] =  -907.1999999999999
# RunBasis: Away from gs at t index  0  and h index  3
#    new_en_states[t,h] =  -924.6
#    ref_en_states[h] =  -928.8
# RunBasis: Away from gs at t index  0  and h index  4
#    new_en_states[t,h] =  -946.8
#    ref_en_states[h] =  -950.4
# RunBasis: Away from gs at t index  0  and h index  5
#    new_en_states[t,h] =  -969.0
#    ref_en_states[h] =  -972.0
# RunBasis: Away from gs at t index  0  and h index  6
#    new_en_states[t,h] =  -992.4
#    ref_en_states[h] =  -993.5999999999999
# RunBasis: Away from gs at t index  0  and h index  7
#    new_en_states[t,h] =  -1013.1
#    ref_en_states[h] =  -1015.2
# RunBasis: Away from gs at t index  0  and h index  74
#    new_en_states[t,h] =  -2461.2
#    ref_en_states[h] =  -2462.4
# RunBasis: Away from gs at t index  0  and h index  75
#    new_en_states[t,h] =  -2483.5
#    ref_en_states[h] =  -2484.0
# RunBasis: Away from gs at t index  0  and h index  76
#    new_en_states[t,h] =  -2504.8
#    ref_en_states[h] =  -2505.6
# RunBasis: Away from gs at t index  0  and h index  77
#    new_en_states[t,h] =  -2526.0
#    ref_en_states[h] =  -2527.2
# RunBasis: Away from gs at t index  0  and h index  78
#    new_en_states[t,h] =  -2542.8
#    ref_en_states[h] =  -2548.8
# RunBasis: Away from gs at t index  0  and h index  79
#    new_en_states[t,h] =  -2564.4
#    ref_en_states[h] =  -2570.4
# RunBasis: Away from gs at t index  0  and h index  80
#    new_en_states[t,h] =  -2592.0
#    ref_en_states[h] =  0.0
# RunBasis: Away from gs at t index  0  and h index  81
#    new_en_states[t,h] =  -2645.3999999999996
#    ref_en_states[h] =  -2656.7999999999997
# RunBasis: Away from gs at t index  0  and h index  82
#    new_en_states[t,h] =  -2717.2000000000007
#    ref_en_states[h] =  -2721.600000000001
# RunBasis: Away from gs at t index  0  and h index  83
#    new_en_states[t,h] =  -2784.6000000000004
#    ref_en_states[h] =  -2786.4000000000005
# -----------Measurements-----------------
# Number of measurement steps =  1280
# ['Energy', 'Magnetisation', 'Si', 'Central_Correlations']
# Measurement period: 1
# itermcs =  1280
# iterreplicas =  4
# ssf =  True
# alternate =  True
# statsfunctions [<function energy at 0x7f8d670f3488>, <function magnetisation at 0x7f8d670f3510>, <function si at 0x7f8d670f3620>, <function centralcorrelations at 0x7f8d670f3598>]
# Time for mcsevolve = 2.044446619600057
# Time for tempering = 0.035081188380718185
# Time for mapping to spins + computing statistics= 0.08689670786261562
# Energies size:  (6, 121)
# Time for all measurements steps =  2773.092038869858
# RunBasis: Away from gs at t index  0  and h index  1
#    new_en_states[t,h] =  -876.6
#    ref_en_states[h] =  -885.6
# RunBasis: Away from gs at t index  0  and h index  2
#    new_en_states[t,h] =  -900.8
#    ref_en_states[h] =  -907.1999999999999
# RunBasis: Away from gs at t index  0  and h index  3
#    new_en_states[t,h] =  -924.0
#    ref_en_states[h] =  -928.8
# RunBasis: Away from gs at t index  0  and h index  4
#    new_en_states[t,h] =  -947.2
#    ref_en_states[h] =  -950.4
# RunBasis: Away from gs at t index  0  and h index  5
#    new_en_states[t,h] =  -969.0
#    ref_en_states[h] =  -972.0
# RunBasis: Away from gs at t index  0  and h index  6
#    new_en_states[t,h] =  -992.4
#    ref_en_states[h] =  -993.5999999999999
# RunBasis: Away from gs at t index  0  and h index  7
#    new_en_states[t,h] =  -1014.5
#    ref_en_states[h] =  -1015.2
# RunBasis: Away from gs at t index  0  and h index  74
#    new_en_states[t,h] =  -2461.8
#    ref_en_states[h] =  -2462.4
# RunBasis: Away from gs at t index  0  and h index  75
#    new_en_states[t,h] =  -2483.0
#    ref_en_states[h] =  -2484.0
# RunBasis: Away from gs at t index  0  and h index  76
#    new_en_states[t,h] =  -2505.2
#    ref_en_states[h] =  -2505.6
# RunBasis: Away from gs at t index  0  and h index  77
#    new_en_states[t,h] =  -2525.1000000000004
#    ref_en_states[h] =  -2527.2
# RunBasis: Away from gs at t index  0  and h index  78
#    new_en_states[t,h] =  -2542.6000000000004
#    ref_en_states[h] =  -2548.8
# RunBasis: Away from gs at t index  0  and h index  79
#    new_en_states[t,h] =  -2563.0
#    ref_en_states[h] =  -2570.4
# RunBasis: Away from gs at t index  0  and h index  80
#    new_en_states[t,h] =  -2592.0
#    ref_en_states[h] =  0.0
# RunBasis: Away from gs at t index  0  and h index  81
#    new_en_states[t,h] =  -2647.0
#    ref_en_states[h] =  -2656.7999999999997
# RunBasis: Away from gs at t index  0  and h index  82
#    new_en_states[t,h] =  -2716.6000000000004
#    ref_en_states[h] =  -2721.600000000001
# RunBasis: Away from gs at t index  0  and h index  83
#    new_en_states[t,h] =  -2785.2000000000007
#    ref_en_states[h] =  -2786.4000000000005
# RunBasis: Away from gs at t index  0  and h index  84
#    new_en_states[t,h] =  -2850.8
#    ref_en_states[h] =  -2851.2000000000003
# Job done

# %%
print(failedupdatesth/(nst*nips))
# Out:
# [[0.55390975 0.88153284 0.97964542 0.99709346 0.99966333 1.00001712
#   1.00007011 1.00007595 1.0000762  1.00007716 1.00007541 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007626 1.00007415 1.00007692
#   1.00007716 1.00007716 1.00007692 1.00007698 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00006776 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.0000768  1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007626 1.00007716 1.00007716
#   1.00007668 1.00007668 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007638 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.0000768  1.00007716 1.00007716 1.00007644
#   1.00007716 1.00007716 1.00007716 1.00005419 1.00007692 1.0000636
#   1.00007716 1.00007716 1.00006721 1.00007716 1.00007716 1.00007716
#   1.00007704 1.00005353 1.00007306 1.00004889 0.99988052 0.99857464
#   0.98929645 0.92581838 0.59950545 0.835557   0.96710202 0.99528815
#   0.99942317 0.99998752 1.0000636  1.00007529 1.00007692 1.00007704
#   1.00007716 1.00007553 1.00005419 1.00007716 1.00007716 1.0000771
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716]
#  [0.55373161 0.75289623 0.88153344 0.94904393 0.97958171 0.99211733
#   0.99703451 0.99895026 0.99964717 0.99991681 1.00001911 1.00005389
#   1.00007107 1.00007529 1.00007559 1.0000762  1.00007035 1.00007704
#   1.00007704 1.00007704 1.00007716 1.00006824 1.00007716 1.00007716
#   1.00007716 1.00007626 1.00007716 1.00007716 1.00007644 1.00007716
#   1.00007692 1.00007716 1.00007668 1.00007716 1.00007716 1.00007716
#   1.00007686 1.00007716 1.00007716 1.00007716 1.00007716 1.00007589
#   1.00007716 1.00007716 1.00007059 1.00007716 1.0000771  1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007294 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007041 1.00007692 1.00007716 1.00007716
#   1.00005419 1.00007716 1.00007716 1.00007716 1.00007704 1.00005558
#   1.00007487 1.00007571 1.00007264 1.00006661 1.00004744 1.00000139
#   0.9998754  0.99951823 0.99860002 0.99604329 0.98925721 0.97102792
#   0.92564375 0.8200434  0.59942949 0.71811469 0.8356558  0.92126332
#   0.96727394 0.9873725  0.99527543 0.99827124 0.99941852 0.9998382
#   0.99998198 1.00004093 1.00006082 1.00006733 1.00007089 1.00007656
#   1.00007692 1.00005281 1.00007716 1.00007716 1.00007589 1.00007716
#   1.00007698 1.00007523 1.00007704 1.00007716 1.00007716 1.0000768
#   1.00007716 1.00007041 1.00007716 1.0000771  1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716]
#  [0.55373113 0.69360472 0.80368019 0.88147238 0.93180489 0.96232886
#   0.97962559 0.98912417 0.99438579 0.99696964 0.99849838 0.99926848
#   0.99965187 0.99986654 0.99995473 1.00001453 1.0000475  1.00006251
#   1.00006782 1.00007397 1.00007451 1.00007614 1.00007632 1.0000771
#   1.00006987 1.00007559 1.00007704 1.00007692 1.00007692 1.00007704
#   1.00007716 1.00007716 1.00007234 1.00007716 1.00007716 1.00007656
#   1.00007614 1.00007656 1.00007505 1.00007541 1.00007716 1.00007385
#   1.00007716 1.00007602 1.00007565 1.00007602 1.00007342 1.00007716
#   1.00005214 1.00007716 1.00007716 1.00007716 1.00007704 1.00007704
#   1.0000771  1.00005516 1.00007716 1.00007692 1.00007668 1.00007656
#   1.00007602 1.00007487 1.0000733  1.00006902 1.00006239 1.00004497
#   1.00001959 0.99997342 0.9998672  0.99967249 0.99928759 0.99856596
#   0.9971652  0.99440478 0.98919633 0.97911151 0.96002098 0.92550197
#   0.86500145 0.76241386 0.59957984 0.67687693 0.75902296 0.83566123
#   0.89740174 0.940423   0.96711396 0.98250078 0.99081037 0.99534511
#   0.99759717 0.99881191 0.99940695 0.99973567 0.99990355 0.99998481
#   1.00003382 1.00005401 1.00005468 1.00007047 1.00007475 1.00007445
#   1.00007674 1.00007674 1.00007704 1.00007644 1.00007686 1.00007716
#   1.00006215 1.00005811 1.00005245 1.00007698 1.00007234 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716]
#  [0.55396828 0.66099169 0.75281033 0.82601068 0.8814048  0.92135748
#   0.94897431 0.96752514 0.97959762 0.98725285 0.99209816 0.99516101
#   0.99705102 0.99823098 0.99894356 0.99939278 0.99964753 0.99981801
#   0.99991434 0.99998403 1.00001748 1.00004178 1.00005359 1.00006438
#   1.00006812 1.00007155 1.00007378 1.00007246 1.00007463 1.00007457
#   1.00007505 1.00007559 1.00007571 1.00007565 1.00007577 1.00007415
#   1.00007372 1.00007529 1.0000721  1.00007342 1.00006806 1.00007385
#   1.00007541 1.00007499 1.00007409 1.00007716 1.00007439 1.00007704
#   1.00007252 1.00007692 1.00007608 1.00007632 1.00007547 1.00007583
#   1.00007523 1.00005365 1.00007174 1.00007125 1.0000419  1.00005883
#   1.00004931 1.00000326 0.99999192 0.99993773 0.99987027 0.99973307
#   0.99947657 0.99914641 0.99857675 0.99759995 0.99599543 0.99341031
#   0.98914557 0.98223036 0.97105197 0.95329747 0.92544247 0.88318173
#   0.81983031 0.72790425 0.59953288 0.65675594 0.71817841 0.77919385
#   0.83576311 0.88374035 0.92112467 0.94846644 0.96721981 0.97953155
#   0.98729866 0.9922602  0.99531256 0.99714374 0.99827582 0.9989684
#   0.99941165 0.99968919 0.99983344 0.99992471 0.9999736  1.00002411
#   1.00004117 1.00005437 1.00006432 1.00006884 1.00007228 1.00007378
#   1.00005009 1.0000733  1.00007662 1.00007662 1.00007583 1.00007692
#   1.00007716 1.00007716 1.00007704 1.00006541 1.00007716 1.00007716
#   1.00007716]
#  [0.55402054 0.64079867 0.71845034 0.78427566 0.83868471 0.88145231
#   0.91461347 0.93922532 0.95730155 0.97047502 0.97956073 0.98609526
#   0.99047472 0.99351345 0.99560649 0.99705398 0.99802765 0.9986896
#   0.99912079 0.99943359 0.99963686 0.99977985 0.99987226 0.99991609
#   0.99996926 0.99998812 1.00000205 1.00001055 1.00001115 1.00001923
#   1.00001459 1.00001923 1.00001585 1.00002092 1.00001115 1.00001507
#   1.00000157 0.99998583 0.99996654 0.99997504 0.99995256 0.99999668
#   1.00000404 1.00003014 1.00003364 1.00004298 1.00004328 1.00005208
#   1.00004593 1.00004624 1.00003762 1.00003695 1.00004009 1.00002315
#   1.00003129 1.00002098 1.0000044  0.99997908 0.99993833 0.99991464
#   0.99983037 0.99976243 0.99956597 0.99937705 0.99903387 0.998536
#   0.99784505 0.99674431 0.9951234  0.99277898 0.9891475  0.98389407
#   0.9760952  0.96476333 0.94847819 0.92557255 0.893154   0.84808003
#   0.78702595 0.7055189  0.59939833 0.64509109 0.69351936 0.74279158
#   0.79102877 0.83576582 0.87489921 0.90768886 0.93334087 0.95294247
#   0.9672139  0.97732892 0.98463222 0.98955259 0.99296266 0.9952996
#   0.99680839 0.99791878 0.99863137 0.99912007 0.99942033 0.99962499
#   0.99979215 0.99987498 0.99994153 0.99998601 1.0000223  1.00003906
#   1.00002749 1.00005757 1.00005775 1.00006794 1.00007161 1.00007372
#   1.00004997 1.00005046 1.00007626 1.00007656 1.00007608 1.00006311
#   1.00007668]
#  [0.55381547 0.62694734 0.69384344 0.75268247 0.80370672 0.84638919
#   0.88164551 0.90961806 0.93179121 0.94893531 0.9621957  0.9720975
#   0.9795204  0.98504678 0.98913719 0.99208635 0.99430091 0.99586384
#   0.99701154 0.99782468 0.99838445 0.9988303  0.99913803 0.99933841
#   0.99946729 0.99955898 0.9996183  0.99965531 0.99966936 0.99964331
#   0.99964826 0.99959328 0.99955012 0.99949737 0.99942576 0.99934721
#   0.99932117 0.99914846 0.99920458 0.99892241 0.99897949 0.99915979
#   0.99931243 0.99947983 0.99958906 0.99960455 0.99970149 0.99969311
#   0.99971041 0.99968111 0.99970534 0.99972186 0.99970305 0.9997042
#   0.99965953 0.99969437 0.99965019 0.99961637 0.99951895 0.99937777
#   0.99918138 0.99888063 0.99850086 0.99788261 0.99711082 0.99600092
#   0.99436168 0.9921567  0.9891516  0.98494062 0.97904827 0.97100477
#   0.96006631 0.9452146  0.92542179 0.89919241 0.86492338 0.81969841
#   0.76228672 0.6894744  0.59958719 0.63725068 0.67696572 0.7181373
#   0.75903586 0.79869635 0.8357886  0.86910663 0.89748077 0.92121835
#   0.94049732 0.95553247 0.96720227 0.97600369 0.98246365 0.98733724
#   0.99080994 0.99344244 0.99530412 0.99663038 0.99761556 0.99832646
#   0.99878484 0.9991531  0.99941533 0.99961378 0.99974525 0.99981126
#   0.99990017 0.99995449 0.99998825 1.00000446 1.00002255 1.00004479
#   1.00005474 1.00005829 1.00006764 1.00006987 1.00006963 1.00006667
#   1.00007372]]

# %%
print(failedupdates/(nsm*measperiod*nips))
# Out:
# [[0.55359212 0.88169723 0.97957278 0.99705711 0.9996869  1.00002658
#   1.00006932 1.00007602 1.00007698 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007704 1.00007397 1.00005184 0.99987401 0.9985439
#   0.98925522 0.92567588 0.59979812 0.83575521 0.96708134 0.99532504
#   0.99940605 0.99998312 1.00006516 1.00007493 1.00007668 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716]
#  [0.55397389 0.75281545 0.88155014 0.9491481  0.97960371 0.99208882
#   0.99708677 0.99896587 0.99965658 0.99992549 1.00002122 1.00005353
#   1.0000695  1.00007481 1.0000762  1.00007704 1.00007704 1.00007692
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007704 1.00007716 1.0000768  1.00007704
#   1.00007662 1.00007589 1.00007246 1.00006498 1.0000513  1.00000633
#   0.99988625 0.99952251 0.99856692 0.9960023  0.9892343  0.97110719
#   0.92577432 0.81982922 0.59959388 0.71800148 0.83581205 0.9213784
#   0.96713234 0.98734622 0.99523184 0.99829656 0.99941394 0.99983513
#   0.99998306 1.00004533 1.00006661 1.00007264 1.00007493 1.00007674
#   1.00007692 1.00007716 1.00007704 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716]
#  [0.55389082 0.69359646 0.80361443 0.88153628 0.93169988 0.96220155
#   0.97958755 0.98916281 0.99429368 0.99709105 0.99849784 0.99926366
#   0.99965603 0.99985852 0.99996419 1.00001977 1.00004606 1.00006324
#   1.00006788 1.00007324 1.00007451 1.00007577 1.00007674 1.00007674
#   1.00007716 1.00007716 1.00007704 1.00007716 1.00007716 1.00007704
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007668
#   1.00007674 1.00007553 1.00007385 1.00006884 1.00006076 1.00004907
#   1.00002502 0.99996769 0.99987323 0.99968189 0.9992803  0.99857723
#   0.99716893 0.99448954 0.98930212 0.97918246 0.9600815  0.92540063
#   0.86485768 0.76233513 0.59957459 0.67712047 0.75920712 0.83588566
#   0.8974827  0.94050811 0.96718738 0.98252122 0.99089669 0.99527048
#   0.99762412 0.99880504 0.99942274 0.99973808 0.99990186 0.99998674
#   1.00003364 1.00005341 1.00006535 1.00007216 1.00007348 1.00007571
#   1.00007656 1.00007704 1.00007698 1.0000768  1.0000771  1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716]
#  [0.55404152 0.66119532 0.75290961 0.82605632 0.88131408 0.92140637
#   0.94904689 0.96755775 0.97954735 0.98723771 0.99213879 0.99511707
#   0.99703366 0.99821645 0.9989168  0.9993873  0.99965609 0.99981331
#   0.99992013 0.99997758 1.00002188 1.0000419  1.00005757 1.00006269
#   1.00006812 1.00007113 1.00007378 1.00007403 1.00007541 1.00007565
#   1.00007559 1.00007704 1.00007583 1.00007662 1.0000768  1.00007692
#   1.00007668 1.00007583 1.00007583 1.00007571 1.00007547 1.00007716
#   1.00007716 1.00007602 1.00007716 1.00007595 1.00007662 1.00007632
#   1.00007602 1.00007632 1.00007608 1.0000765  1.00007571 1.00007602
#   1.00007559 1.00007505 1.00007282 1.00006896 1.00006559 1.0000601
#   1.00004883 1.00002936 0.99999934 0.99995141 0.99987359 0.99973295
#   0.99951931 0.99914141 0.99855421 0.99760296 0.99602322 0.99345191
#   0.98917486 0.98230511 0.97103353 0.95314923 0.92562422 0.88325798
#   0.81983573 0.727877   0.59938344 0.65688392 0.71806918 0.77906576
#   0.83582996 0.88376591 0.92117169 0.94837047 0.96718117 0.97951835
#   0.9872992  0.99225471 0.99525198 0.99714663 0.99830988 0.99900511
#   0.99942425 0.999679   0.99983374 0.99993068 0.99999029 1.00002375
#   1.00004232 1.00005739 1.00006438 1.00006908 1.00007174 1.00007463
#   1.00007589 1.00007608 1.00007686 1.00007668 1.0000765  1.00007704
#   1.00007716 1.00007716 1.00007716 1.00007716 1.00007716 1.00007716
#   1.00007716]
#  [0.55377273 0.64100502 0.71807786 0.78428795 0.83864173 0.88162712
#   0.91439182 0.93930875 0.95725556 0.9702902  0.97956483 0.98603986
#   0.99042927 0.99349218 0.99560963 0.99704879 0.99800612 0.99866934
#   0.9991214  0.99941684 0.99965007 0.99977877 0.99986955 0.9999317
#   0.99996889 1.0000006  1.00001344 1.00002333 1.00002598 1.00003237
#   1.00003472 1.00002948 1.00002942 1.00003092 1.00003406 1.00002761
#   1.00003563 1.00003135 1.00001326 1.00003737 1.00000199 1.00003315
#   1.00003973 1.00004461 1.00004545 1.0000513  1.00005642 1.00005046
#   1.00004804 1.0000554  1.00005238 1.00005112 1.00004425 1.00004431
#   1.00003502 1.00002827 1.00002007 0.99999717 0.99997384 0.99991983
#   0.99985593 0.99975285 0.99959406 0.99937729 0.999059   0.9985448
#   0.9978248  0.99673937 0.99512852 0.99275656 0.9892129  0.98395918
#   0.97608851 0.9648329  0.94858254 0.92550154 0.8932458  0.84832037
#   0.78698586 0.70520671 0.59908523 0.6452131  0.69354565 0.74289388
#   0.791143   0.83571048 0.87503894 0.90757378 0.93329644 0.95286235
#   0.9671447  0.97737697 0.9846195  0.98957682 0.99298159 0.99531841
#   0.99683853 0.99791727 0.99860948 0.99911416 0.99942515 0.99963421
#   0.99977328 0.99987425 0.99994249 0.99998897 1.00001634 1.00004141
#   1.00005142 1.00005853 1.00006733 1.00006902 1.00007149 1.00007294
#   1.00007505 1.00007529 1.00007583 1.00007656 1.00007716 1.00007698
#   1.00007704]
#  [0.55427421 0.62700201 0.69382861 0.75263871 0.80374222 0.84638883
#   0.88143609 0.90948712 0.93191846 0.948845   0.96222915 0.9720629
#   0.97954668 0.98507186 0.9891387  0.99210672 0.9942255  0.9958211
#   0.99698911 0.99781811 0.99838403 0.99885405 0.999161   0.99937801
#   0.99952269 0.99964319 0.9996966  0.99973356 0.99975508 0.99975013
#   0.99972554 0.9996995  0.999679   0.99961673 0.99958894 0.99950075
#   0.99946928 0.99943516 0.99938832 0.99935324 0.99927294 0.99939827
#   0.9994612  0.99955169 0.99968629 0.99967394 0.99975514 0.99971294
#   0.99972138 0.99974983 0.99974706 0.99980288 0.99979571 0.99980975
#   0.99979492 0.99977762 0.9997341  0.99967611 0.99959147 0.99944613
#   0.99922755 0.99893416 0.99852135 0.99790564 0.99710461 0.99597686
#   0.99443727 0.99223705 0.98913906 0.98493833 0.97911621 0.97089464
#   0.96000434 0.94515685 0.92545103 0.89921562 0.86461787 0.81974983
#   0.76243713 0.68964802 0.59959298 0.63712933 0.67692582 0.71810637
#   0.75921073 0.79897738 0.83585136 0.86887882 0.89748035 0.92127315
#   0.94041329 0.9555778  0.96719124 0.97606168 0.98253171 0.98736322
#   0.99084973 0.99344449 0.99529056 0.99665256 0.99764299 0.99832224
#   0.99879292 0.99916902 0.99941738 0.99960913 0.99974031 0.99983314
#   0.99990204 0.99995388 0.99998734 1.00001302 1.00003153 1.00004437
#   1.00005498 1.00005944 1.00006522 1.00006842 1.00007143 1.00007222
#   1.00007312]]

# %%
print(4*swapst/(nrps*nsm*measperiod*nh))
# Out:
# [0.76083419 0.64953512 0.54613895 0.45508781 0.38311596 0.        ]

# %%
print(4*swapsh/(nrps*nsm*measperiod*nt))
# Out:
# [0.00690104 0.01328125 0.01432292 0.02513021 0.03476563 0.03828125
#  0.08333333 0.13242187 0.25052083 0.34596354 0.39088542 0.47734375
#  0.51328125 0.56731771 0.62916667 0.67825521 0.71276042 0.74322917
#  0.78216146 0.81028646 0.83177083 0.85572917 0.86809896 0.88255208
#  0.90520833 0.91289062 0.92044271 0.93697917 0.94257813 0.94361979
#  0.95690104 0.96015625 0.96770833 0.97135417 0.97460938 0.98046875
#  0.98333333 0.98789063 0.98893229 0.99127604 0.99375    0.99309896
#  0.99361979 0.99270833 0.9921875  0.99036458 0.98554688 0.98138021
#  0.97578125 0.97526042 0.96888021 0.96393229 0.95755208 0.94166667
#  0.93984375 0.93463542 0.92291667 0.90442708 0.90208333 0.88658854
#  0.87578125 0.85234375 0.82682292 0.80039063 0.771875   0.74140625
#  0.70351562 0.66302083 0.60729167 0.54947917 0.50598958 0.44192708
#  0.39661458 0.26640625 0.17473958 0.15026042 0.07981771 0.02708333
#  0.02070312 0.0171875  0.01263021 0.01041667 0.00677083 0.01835938
#  0.08242188 0.16289063 0.21875    0.29388021 0.37513021 0.46276042
#  0.53151042 0.60520833 0.66263021 0.72539062 0.76992187 0.80950521
#  0.85013021 0.87447917 0.90664062 0.91888021 0.93671875 0.95
#  0.96015625 0.97070312 0.975      0.98007813 0.98763021 0.98984375
#  0.99414062 0.9953125  0.99596354 0.99752604 0.99765625 0.99882812
#  0.99882812 0.99934896 0.99973958 0.99960938 0.99960938 1.
#  0.49973958]
